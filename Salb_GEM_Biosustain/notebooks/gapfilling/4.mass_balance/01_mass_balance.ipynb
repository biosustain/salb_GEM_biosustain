# %%
import cobra
from cobra.core import Metabolite
from cobra.io import load_model, read_sbml_model, load_json_model, write_sbml_model
from cobra.flux_analysis import gapfill
import os, re
import pandas as pd

print(os.getcwd())

ext_dir = '/../../../data/external'
uni_dir = '/../2.gapfill_w_universal'
man_dir = '/../3.manual_check'
mas_dir = '/../4.mass_balance'
# Import model
# model = read_sbml_model(f"{os.getcwd()}/{ext_dir}/Salb-GEM.xml")
# model = read_sbml_model(f"{os.getcwd()}/{uni_dir}/Salb-GEM-Uni-gapfill.xml")
# model = read_sbml_model(f"{os.getcwd()}/{man_dir}/Salb-GEM-Man-gapfill.xml")
model = read_sbml_model(f"{os.getcwd()}/{mas_dir}/Salb-GEM-Biosustain.xml")
# Out:
# /Users/te/Library/CloudStorage/OneDrive-Personal/Biosustain/strep/Code/streptsd/notebooks/gapfilling/4.mass_balance
# '' is not a valid SBML 'SId'.

# %% [markdown]
# # 1. Find metabolites that doesn't have formula or charge

# %%
no_formula = [m.id for m in model.metabolites if m.formula == None]
print(no_formula)
len(no_formula)
# Out:
# ['12da3oaglcpyr_c', '14hdphet_c', '15cphyt_c', '1acpc_c', '1p4h2cbxl_c', '24dclphen_c', '24ddhrham_c', '24dh5m6o24d_c', '25dc25chx_c', '25dclpql_c', '26hxcho_c', '2a5ocyc1eccoa_c', '2amac_c', '2chloacr_c', '2clprop_c', '2cm3hppc_c', '2dh3dgal6p_c', '2dh3dogal_c', '2dh3dorham_c', '2dhglcn_c', '2hdhepdd_c', '2hmc_c', '2hmcnsad_c', '2kmb_c', '2mfumcoa_c', '2mop_c', '2ohed_c', '2oph_c', '2pglyc_c', '2ppoh_c', '33biflav_c', '38biflav_c', '3aib_c', '3ambutcoa_c', '3clbxal_c', '3clbzat_c', '3dclcatc_c', '3h4oxbut_c', '3hbcoa__R_c', '3hcinnm_c', '3hpppn_c', '3metbzal_c', '3oc4en24ocoa_c', '3ocd26ocoa_c', '3ocdncoa_c', '3oce26ocoa_c', '3ocl4e26ocoa_c', '3ophb_c', '3ovobenz_c', '3spyr_c', '3sulprop_c', '3uribut_c', '44dpcop_c', '45secdop_c', '4aabutn_c', '4gglutbut_c', '4guanbut_c', '4gubuty_c', '4h2mohexn_c', '4hbald_c', '4hbutcoa_c', '4hbz_c', '4hphac_c', '4mbzald_c', '4nitrocc_c', '4nitroph_c', '4sulbza_c', '4sulfbenz_c', '56dthm_c', '56dura_c', '5a2opntn_c', '5am3ohex_c', '5c2oh3ed_c', '5cmhm_c', '5cmhmsa_c', '5g2oxpt_c', '5hiu_c', '6a6doxf_c', '6p2dgluc_c', 'ETFred_c', 'HC00591_c', 'HC01115_c', 'L2aadp_c', 'Lcyst_c', 'Nforglu_c', 'Sfglutth_c', 'aa_c', 'abacptri_c', 'acetoin_c', 'acetone_c', 'acmana_c', 'acnam__B_c', 'acryl_c', 'agdppdtundec_c', 'ahgalac__L_c', 'ahop_c', 'albflon_c', 'allphn_c', 'amuco_c', 'amucsam_c', 'anthrancoa_c', 'ap4a_c', 'arg__D_c', 'ascb__L_c', 'at44dcop_c', 'atphyflu_c', 'bmmcoa_c', 'butanoate_c', 'bz_c', 'bzal_c', 'bzamid_c', 'bzsuccoa__R_c', 'cala_c', 'caro_c', 'catechol_c', 'catechol_e', 'cechddd_c', 'ch15deccoa_c', 'chdpro__D_c', 'chlorac_c', 'chol4e3o_c', 'cholate_c', 'chsterol_c', 'cinnm_c', 'cmpacna_c', 'cmpglna_c', 'co_c', 'crn_c', 'crtn_c', 'cyan_c', 'cyccarcoa_c', 'cychex_c', 'cychxaol_c', 'd11oxpen_c', 'decda_tb_c', 'dh7oxcho_c', 'dhcinnm_c', 'dhiconf_c', 'dhiconfa_c', 'dhpppn_c', 'dim1oct_c', 'dmppat_c', 'dolichol_c', 'dolmanp_c', 'dopa__L_c', 'dpperypfur_c', 'dtdp26ddgh2e2u_c', 'dtdp34dh26doglc_c', 'dtdp4dh26dall_c', 'dtdp4h26dthp_c', 'ecaplac_c', 'enter_c', 'enter_e', 'episz_c', 'etf_ox_c', 'fc1p_c', 'feroxG1_c', 'flaviolin_c', 'formhop_c', 'formyct_c', 'frdp_2_c', 'fruur_c', 'fumpyr_c', 'g6p_B_c', 'ga_c', 'gcarote_c', 'gcgguaiac_c', 'gcgguaiace_c', 'geosmin_c', 'geranial_c', 'geraniol_c', 'gg4abut_c', 'ggaggdcap_c', 'ggcysto_c', 'ggputresc_c', 'ghb_c', 'glucys_c', 'grmcrol_c', 'gullac_c', 'guln__L_c', 'haphenon_c', 'hccystox_c', 'hdoxcad_c', 'hercyn_c', 'hmgth_c', 'hmmsh_c', 'hop22en_c', 'hosuprop_c', 'hsql_c', 'hyxsuccad_c', 'indpyr_c', 'itaccoa_c', 'itacon_c', 'kdo2laur_c', 'kdo2lipid4_c', 'lald__D_c', 'lgt__S_c', 'lycop_c', 'm_tol_c', 'malpyr_c', 'malylcoa_c', 'mana_c', 'metbute_c', 'methydan_c', 'mnl1p_c', 'mphpv__R_c', 'mphpv__S_c', 'mppate_c', 'mppp9_c', 'mthgxl_c', 'mycthigpyrpp_c', 'n4abutn_c', 'n6hxlys_c', 'nacitrul__L_c', 'nacpphin_c', 'nadhx__R_c', 'nadhx__S_c', 'nadphx__R_c', 'nadphx__S_c', 'nal2a6o_c', 'neuspn_c', 'nic1ox_c', 'nico__S_c', 'nisirhcl_c', 'nndmyani_c', 'nphtatt_c', 'nsirhcda_c', 'orn__D_c', 'p_tol_c', 'paolac_c', 'pcumald_c', 'pcumat_c', 'pentlacF_c', 'pentlacd_c', 'phitcoa_c', 'ppdyletamin_c', 'pphinit_c', 'pppn_c', 'pre1_c', 'prephytedp_c', 'pro__D_c', 'prp13da_c', 'prp2enoate_c', 'prpncoa_c', 'psqldi_c', 'puri4pp_c', 'pyr2cbox_c', 'pyrgal_c', 'rib1mpp5tpp_c', 'ru1p__D_c', 'sbt6p_c', 'sl__L_c', 'sorb14lac_c', 'stmyn_c', 'strep6p_c', 'tbutalc_c', 'tbutfor_c', 'tbutmet_c', 'tcl14bzq_c', 'tclhqn_c', 'tcynt_c', 'tma_c', 'tmao_c', 'todcpribfur_c', 'tsul_c', 'uGgl_c', 'uGgla_c', 'unaga_c', 'vanln_c', 'xyhex3u14lac_c', 'zcarote_c', 'biomass_c', 'g1p_B_c', '23dhb_c', 'Glc_aD_c', 'rbl__D_c', 'ethamp_c', 'retinal_c', 'trypta_c', '5aptn_c', 'retinol_c', 'tym_c', 'rbl__L_c', 'ocdce9coa_c', 'hxdcal_c', 'nrpphr_c', '3sala_c', 'id3acald_c', 'srtn_c', '5apentam_c', 'ficytb5_c', 'focytb5_c', '3hpp_c', 'ru5p__L_c', 'sph1p_c', 'seln_c', 'cbm_c', '5oxpro_c', 'aact_c', '2mcit_c', 'fru_B_c', 'C02356_c', 'pad_c', 'aprut_c', 'ind3acnl_c', 'dopa_c', '4hoxpacd_c', '34dhpac_c', '23ddhb_c',  ...
# 360

# %%
# From the model, we found that if the charge is not documented in the notes, then the charge is missing.

no_charge = [m.id for m in model.metabolites if "CHARGE" not in m.notes.keys()]
print(no_charge)
len(no_charge)
# Out:
# ['mmcoa_c', 'ethmalcoa_c', 'pprdn_c', 'xu1p__D_c', 'citr__L_e', 'acgam_e', '2mygydpp_c', 'alltn_e', 'h2s_e', '2mborn_c', 'gam_e', 'xylu__L_c', 'salcn_e', 'agm_e']
# 14

# %% [markdown]
# # 2. Fix metabolite formula and charge using pubchem and METANETX

# %%
import json, requests

def get_pubchem_formula_charge(query):
    url = f"https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/{query}/property/MolecularFormula,Charge/JSON"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        properties = data.get('PropertyTable', {}).get('Properties', [])[0]
        formula = properties.get('MolecularFormula').split("-")[0]
        charge = properties.get('Charge')
        return formula, charge
    else:
        print(f"Failed to retrieve data for {query}")
        return None, None

still_failed = []
for f in no_formula:
    met = model.metabolites.get_by_id(f)
    formula, charge = get_pubchem_formula_charge(met.name)
    print(f"Metabolite: {met.id}, Formula: {formula}, Charge: {charge}")

    if formula != None:
        met.formula = formula
    else:
        still_failed.append(met.id)

    if charge != None:
        met.charge = charge
# Out:
# Failed to retrieve data for 12-DIACYL-3-O-ALPHA-D-GLUCOPYRANOSYL
# Metabolite: 12da3oaglcpyr_c, Formula: None, Charge: None
# Metabolite: 14hdphet_c, Formula: C8H10O2, Charge: 0
# Metabolite: 15cphyt_c, Formula: C40H64, Charge: 0
# Metabolite: 1acpc_c, Formula: C4H6NO2, Charge: -1
# Metabolite: 1p4h2cbxl_c, Formula: C5H7NO3, Charge: 0
# Metabolite: 24dclphen_c, Formula: C6H4Cl2O, Charge: 0
# Metabolite: 24ddhrham_c, Formula: C6H7O5, Charge: -1
# Metabolite: 24dh5m6o24d_c, Formula: C7H7O5, Charge: -1
# Metabolite: 25dc25chx_c, Formula: C6H6Cl2O2, Charge: 0
# Metabolite: 25dclpql_c, Formula: C6H4Cl2O2, Charge: 0
# Metabolite: 26hxcho_c, Formula: C27H44O2, Charge: 0
# Metabolite: 2a5ocyc1eccoa_c, Formula: C28H43N8O18P3S, Charge: 0
# Metabolite: 2amac_c, Formula: C3H4NO2, Charge: -1
# Metabolite: 2chloacr_c, Formula: C3H2ClO2, Charge: -1
# Metabolite: 2clprop_c, Formula: C3H4ClO2, Charge: -1
# Metabolite: 2cm3hppc_c, Formula: C32H41N7O20P3S, Charge: -5
# Failed to retrieve data for 2-dehydro-3-deoxy-D-galactonate6-phosphate
# Metabolite: 2dh3dgal6p_c, Formula: None, Charge: None
# Metabolite: 2dh3dogal_c, Formula: C6H9O6, Charge: -1
# Metabolite: 2dh3dorham_c, Formula: C6H9O5, Charge: -1
# Metabolite: 2dhglcn_c, Formula: C6H10O7, Charge: 0
# Metabolite: 2hdhepdd_c, Formula: C7H6O5, Charge: -2
# Metabolite: 2hmc_c, Formula: C6H4O5, Charge: -2
# Metabolite: 2hmcnsad_c, Formula: C6H5O4, Charge: -1
# Metabolite: 2kmb_c, Formula: C5H7O3S, Charge: -1
# Metabolite: 2mfumcoa_c, Formula: C26H35N7O19P3S, Charge: -5
# Failed to retrieve data for CPD-12179
# Metabolite: 2mop_c, Formula: None, Charge: None
# Metabolite: 2ohed_c, Formula: C7H6O5, Charge: -2
# Metabolite: 2oph_c, Formula: C46H70O, Charge: 0
# Metabolite: 2pglyc_c, Formula: C2H2O6P, Charge: -3
# Metabolite: 2ppoh_c, Formula: C3H8O, Charge: 0
# Metabolite: 33biflav_c, Formula: C20H10O10, Charge: 0
# Metabolite: 38biflav_c, Formula: C20H10O10, Charge: 0
# Metabolite: 3aib_c, Formula: C4H9NO2, Charge: 0
# Metabolite: 3ambutcoa_c, Formula: C25H40N8O17P3S, Charge: -3
# Metabolite: 3clbxal_c, Formula: C7H5ClO, Charge: 0
# Metabolite: 3clbzat_c, Formula: C7H4ClO2, Charge: -1
# Metabolite: 3dclcatc_c, Formula: C6H4Cl2O2, Charge: 0
# Metabolite: 3h4oxbut_c, Formula: C4H5O4, Charge: -1
# Metabolite: 3hbcoa__R_c, Formula: C25H42N7O18P3S, Charge: 0
# Failed to retrieve data for 3-hydroxy-trans-cinnamate
# Metabolite: 3hcinnm_c, Formula: None, Charge: None
# Metabolite: 3hpppn_c, Formula: C9H9O3, Charge: -1
# Metabolite: 3metbzal_c, Formula: C8H8O, Charge: 0
# Metabolite: 3oc4en24ocoa_c, Formula: C45H70N7O18P3S, Charge: 0
# Metabolite: 3ocd26ocoa_c, Formula: C48H70N7O18P3S, Charge: -4
# Metabolite: 3ocdncoa_c, Formula: C45H64N7O18P3S, Charge: -4
# Metabolite: 3oce26ocoa_c, Formula: C48H76N7O18P3S, Charge: 0
# Metabolite: 3ocl4e26ocoa_c, Formula: C48H72N7O18P3S, Charge: -4
# Metabolite: 3ophb_c, Formula: C47H69O3, Charge: -1
# Metabolite: 3ovobenz_c, Formula: C10H8O5, Charge: 0
# Metabolite: 3spyr_c, Formula: C3H4O6S, Charge: 0
# Metabolite: 3sulprop_c, Formula: C3H7O5S, Charge: -1
# Metabolite: 3uribut_c, Formula: C5H9N2O3, Charge: -1
# Failed to retrieve data for 4,4'-diapolycopenedial
# Metabolite: 44dpcop_c, Formula: None, Charge: None
# Metabolite: 45secdop_c, Formula: C9H11NO6, Charge: 0
# Metabolite: 4aabutn_c, Formula: C6H11NO3, Charge: 0
# Metabolite: 4gglutbut_c, Formula: C9H16N2O4, Charge: 0
# Metabolite: 4guanbut_c, Formula: C5H11N3O2, Charge: 0
# Metabolite: 4gubuty_c, Formula: C5H12N4O, Charge: 0
# Metabolite: 4h2mohexn_c, Formula: C7H6O5, Charge: -2
# Metabolite: 4hbald_c, Formula: C7H6O2, Charge: 0
# Metabolite: 4hbutcoa_c, Formula: C25H42N7O18P3S, Charge: 0
# Metabolite: 4hbz_c, Formula: C7H5O3, Charge: -1
# Metabolite: 4hphac_c, Formula: C8H7O3, Charge: -1
# Metabolite: 4mbzald_c, Formula: C8H8O, Charge: 0
# Metabolite: 4nitrocc_c, Formula: C6H5NO4, Charge: 0
# Metabolite: 4nitroph_c, Formula: C6H5NO3, Charge: 0
# Metabolite: 4sulbza_c, Formula: C7H6O4S, Charge: 0
# Metabolite: 4sulfbenz_c, Formula: C7H6O5S, Charge: 0
# Metabolite: 56dthm_c, Formula: C5H8N2O2, Charge: 0
# Metabolite: 56dura_c, Formula: C4H6N2O2, Charge: 0
# Metabolite: 5a2opntn_c, Formula: C5H8NO3, Charge: -1
# Metabolite: 5am3ohex_c, Formula: C6H11NO3, Charge: 0
# Metabolite: 5c2oh3ed_c, Formula: C8H5O7, Charge: -3
# Metabolite: 5cmhm_c, Formula: C8H8O7, Charge: 0
# Failed to retrieve data for 2-hydroxy-5-carboxymethylmuconatesemialdehyde
# Metabolite: 5cmhmsa_c, Formula: None, Charge: None
# Metabolite: 5g2oxpt_c, Formula: C6H10N3O3, Charge: -1
# Metabolite: 5hiu_c, Formula: C5H4N4O4, Charge: 0
# Metabolite: 6a6doxf_c, Formula: C19H18N5O6, Charge: -1
# Metabolite: 6p2dgluc_c, Formula: C6H8O10P, Charge: -3
# Failed to retrieve data for ETF-Reduced
# Metabolite: ETFred_c, Formula: None, Charge: None
# Metabolite: HC00591_c, Formula: C5H6NO4, Charge: -1
# Metabolite: HC01115_c, Formula: C11H19NO10, Charge: 0
# Metabolite: L2aadp_c, Formula: C6H11NO4, Charge: 0
# Metabolite: Lcyst_c, Formula: C3H6NO5S, Charge: -1
# Metabolite: Nforglu_c, Formula: C6H9NO5, Charge: 0
# Metabolite: Sfglutth_c, Formula: C11H17N3O7S, Charge: 0
# Metabolite: aa_c, Formula: C3H5NO, Charge: 0
# Metabolite: abacptri_c, Formula: C35H63NO3, Charge: 0
# Metabolite: acetoin_c, Formula: C4H8O2, Charge: 0
# Metabolite: acetone_c, Formula: C3H6O, Charge: 0
# Metabolite: acmana_c, Formula: C8H15NO6, Charge: 0
# Metabolite: acnam__B_c, Formula: C11H18NO9, Charge: -1
# Metabolite: acryl_c, Formula: C3H3O2, Charge: -1
# Failed to retrieve data for beta-D-GlcA-(1rarr2)-alpha-D-Man-(1rarr3)-beta-D-Glc-(1rarr4)-alpha-D-Glc-1-diphospho-ditrans,octacis-undecaprenol
# Metabolite: agdppdtundec_c, Formula: None, Charge: None
# Metabolite: ahgalac__L_c, Formula: C6H9O6, Charge: -1
# Metabolite: ahop_c, Formula: C40H63N5O3, Charge: 0
# Metabolite: albflon_c, Formula: C15H22O, Charge: 0
# Metabolite: allphn_c, Formula: C2H3N2O3, Charge: -1
# Metabolite: amuco_c, Formula: C6H6NO4, Charge: -1
# Metabolite: amucsam_c, Formula: C6H7NO3, Charge: 0
# Metabolite: anthrancoa_c, Formula: C28H41N8O17P3S, Charge: 0
# Failed to retrieve data for 5',5'''-diadenosinetetraphosphate
# Metabolite: ap4a_c, Formula: None, Charge: None
# Metabolite: arg__D_c, Formula: C6H14N4O2, Charge: 0
# Metabolite: ascb__L_c, Formula: C6H8O6, Charge: 0
# Failed to retrieve data for all-trans-4,4'-diapolycopene
# Metabolite: at44dcop_c, Formula: None, Charge: None
# Failed to retrieve data for all-transphytofluene
# Metabolite: atphyflu_c, Formula: None, Charge: None
# Metabolite: bmmcoa_c, Formula: C26H37N7O20P3S, Charge: -5
# Metabolite: butanoate_c, Formula: C4H7O2, Charge: -1
# Metabolite: bz_c, Formula: C7H5O2, Charge: -1
# Metabolite: bzal_c, Formula: C7H6O, Charge: 0
# Metabolite: bzamid_c, Formula: C7H7NO, Charge: 0
# Metabolite: bzsuccoa__R_c, Formula: C32H46N7O19P3S, Charge: 0
# Metabolite: cala_c, Formula: C4H8N2O3, Charge: 0
# Metabolite: caro_c, Formula: C40H56, Charge: 0
# Metabolite: catechol_c, Formula: C6H6O2, Charge: 0
# Metabolite: catechol_e, Formula: C6H6O2, Charge: 0
# Metabolite: cechddd_c, Formula: C9H11O4, Charge: -1
# Metabolite: ch15deccoa_c, Formula: C28H42N7O17P3S, Charge: 0
# Metabolite: chdpro__D_c, Formula: C5H9NO3, Charge: 0
# Metabolite: chlorac_c, Formula: C2H2ClO2, Charge: -1
# Metabolite: chol4e3o_c, Formula: C27H44O, Charge: 0
# Metabolite: cholate_c, Formula: C24H40O5, Charge: 0
# Metabolite: chsterol_c, Formula: C27H46O, Charge: 0
# Metabolite: cinnm_c, Formula: C9H8O2, Charge: 0
# Metabolite: cmpacna_c, Formula: C20H29N4O16P, Charge: -2
# Metabolite: cmpglna_c, Formula: C20H29N4O17P, Charge: -2
# Metabolite: co_c, Formula: CH2O, Charge: 0
# Metabolite: crn_c, Formula: C7H15NO3, Charge: 0
# Metabolite: crtn_c, Formula: C4H7N3O, Charge: 0
# Metabolite: cyan_c, Formula: CHN, Charge: 0
# Metabolite: cyccarcoa_c, Formula: C28H44N7O17P3S, Charge: 0
# Metabolite: cychex_c, Formula: C6H10O, Charge: 0
# Metabolite: cychxaol_c, Formula: C6H12O, Charge: 0
# Metabolite: d11oxpen_c, Formula: C15H19O3, Charge: -1
# Metabolite: decda_tb_c, Formula: C55H91O8P, Charge: 0
# Metabolite: dh7oxcho_c, Formula: C24H37O5, Charge: -1
# Metabolite: dhcinnm_c, Formula: C9H7O4, Charge: -1
# Failed to retrieve data for (-)-dehydrodiconiferylacid
# Metabolite: dhiconf_c, Formula: None, Charge: None
# Failed to retrieve data for (-)-dehydrodiconiferylaldehyde
# Metabolite: dhiconfa_c, Formula: None, Charge: None
# Metabolite: dhpppn_c, Formula: C9H9O4, Charge: -1
# Metabolite: dim1oct_c, Formula: C12H20, Charge: 0
# Metabolite: dmppat_c, Formula: C8H11NO, Charge: 0
# Failed to retrieve data for DOLICHOLP
# Metabolite: dolichol_c, Formula: None, Charge: None
# Failed to retrieve data for Dolichyl phosphate D-mannose
# Metabolite: dolmanp_c, Formula: None, Charge: None
# Metabolite: dopa__L_c, Formula: C9H11NO4, Charge: 0
# Metabolite: dpperypfur_c, Formula: C55H89O8P, Charge: 0
# Metabolite: dtdp26ddgh2e2u_c, Formula: C16H22N2O14P2, Charge: 0
# Metabolite: dtdp34dh26doglc_c, Formula: C16H22N2O14P2, Charge: 0
# Metabolite: dtdp4dh26dall_c, Formula: C16H22N2O14P2, Charge: -2
# Metabolite: dtdp4h26dthp_c, Formula: C16H22N2O14P2, Charge: -2
# Metabolite: ecaplac_c, Formula: C6H10O2, Charge: 0
# Metabolite: enter_c, Formula: C30H27N3O15, Charge: 0
# Metabolite: enter_e, Formula: C30H27N3O15, Charge: 0
# Metabolite: episz_c, Formula: C15H24, Charge: 0
# Failed to retrieve data for ETF-Oxidized
# Metabolite: etf_ox_c, Formula: None, Charge: None
# Failed to retrieve data for L-fuculose1-phosphate
# Metabolite: fc1p_c, Formula: None, Charge: None
# Failed to retrieve data for desferrioxamineG1
# Metabolite: feroxG1_c, Formula: None, Charge: None
# Metabolite: flaviolin_c, Formula: C10H6O5, Charge: 0
# Failed to retrieve data for formylhopane
# Metabolite: formhop_c, Formula: None, Charge: None
# Metabolite: formyct_c, Formula: C18H30N2O13S, Charge: 0
# Failed to retrieve data for (2Z,6E)-farnesyldiphosphate
# Metabolite: frdp_2_c, Formula: None, Charge: None
# Failed to retrieve data for FRUCTURONATE
# Metabolite: fruur_c, Formula: None, Charge: None
# Metabolite: fumpyr_c, Formula: C7H6O6, Charge: 0
# Metabolite: g6p_B_c, Formula: C6H13O9P, Charge: 0
# Metabolite: ga_c, Formula: C7H6O5, Charge: 0
# Metabolite: gcarote_c, Formula: C40H56, Charge: 0
# Failed to retrieve data for (-)-(alphaS,betaR)-guaiacylglycerol-beta-guaiacylether
# Metabolite: gcgguaiac_c, Formula: None, Charge: None
# Failed to retrieve data for (+)-(alphaS,betaS)-guaiacylglycerol-beta-guaiacylether
# Metabolite: gcgguaiace_c, Formula: None, Charge: None
# Metabolite: geosmin_c, Formula: C12H22O, Charge: 0
# Metabolite: geranial_c, Formula: C10H16O, Charge: 0
# Metabolite: geraniol_c, Formula: C10H18O, Charge: 0
# Metabolite: gg4abut_c, Formula: C9H15N2O5, Charge: -1
# Metabolite: ggaggdcap_c, Formula: C85H137O33P2, Charge: -3
# Failed to retrieve data for gamma-L-glutamyl-S-(hercyn-2-yl)-L-cysteineS-oxide
# Metabolite: ggcysto_c, Formula: None, Charge: None
# Metabolite: ggputresc_c, Formula: C9H19N3O3, Charge: 0
# Metabolite: ghb_c, Formula: C4H7O3, Charge: -1
# Metabolite: glucys_c, Formula: C8H14N2O5S, Charge: 0
# Metabolite: grmcrol_c, Formula: C15H26O, Charge: 0
# Metabolite: gullac_c, Formula: C6H10O6, Charge: 0
# Metabolite: guln__L_c, Formula: C6H11O7, Charge: -1
# Metabolite: haphenon_c, Formula: C8H8O2, Charge: 0
# Failed to retrieve data for S-(hercyn-2-yl)-L-cysteineS-oxide
# Metabolite: hccystox_c, Formula: None, Charge: None
# Metabolite: hdoxcad_c, Formula: C5H14N2O, Charge: 0
# Metabolite: hercyn_c, Formula: C9H15N3O2, Charge: 0
# Metabolite: hmgth_c, Formula: C11H19N3O7S, Charge: 0
# Failed to retrieve data for S-hydroxymethylmycothiol
# Metabolite: hmmsh_c, Formula: None, Charge: None
# Metabolite: hop22en_c, Formula: C30H50, Charge: 0
# Metabolite: hosuprop_c, Formula: C3H5O5S, Charge: -1
# Metabolite: hsql_c, Formula: C30H50O, Charge: 0
# Metabolite: hyxsuccad_c, Formula: C9H18N2O4, Charge: 0
# Metabolite: indpyr_c, Formula: C11H9NO3, Charge: 0
# Metabolite: itaccoa_c, Formula: C26H40N7O19P3S, Charge: 0
# Metabolite: itacon_c, Formula: C5H6O4, Charge: 0
# Failed to retrieve data for alpha-Kdo-(2->4)-alpha-Kdo-(2->6)-(lauroyl)-lipidIVA
# Metabolite: kdo2laur_c, Formula: None, Charge: None
# Failed to retrieve data for alpha-Kdo-(2->4)-alpha-Kdo-(2->6)-lipidIVA
# Metabolite: kdo2lipid4_c, Formula: None, Charge: None
# Metabolite: lald__D_c, Formula: C3H6O2, Charge: 0
# Metabolite: lgt__S_c, Formula: C13H21N3O8S, Charge: 0
# Metabolite: lycop_c, Formula: C40H56, Charge: 0
# Metabolite: m_tol_c, Formula: C8H7O2, Charge: -1
# Metabolite: malpyr_c, Formula: C7H4O6, Charge: -2
# Metabolite: malylcoa_c, Formula: C25H35N7O20P3S, Charge: -5
# Metabolite: mana_c, Formula: C6H11O7, Charge: -1
# Failed to retrieve data for methyltert-butylether
# Metabolite: metbute_c, Formula: None, Charge: None
# Metabolite: methydan_c, Formula: C4H6N2O2, Charge: 0
# Metabolite: mnl1p_c, Formula: C6H15O9P, Charge: 0
# Metabolite: mphpv__R_c, Formula: C17H18O6, Charge: 0
# Metabolite: mphpv__S_c, Formula: C17H18O6, Charge: 0
# Metabolite: mppate_c, Formula: CH3O3P, Charge: -2
# Metabolite: mppp9_c, Formula: C34H32MgN4O4, Charge: 0
# Metabolite: mthgxl_c, Formula: C3H4O2, Charge: 0
# Failed to retrieve data for mycothiol-arsenateconjugate
# Metabolite: mycthigpyrpp_c, Formula: None, Charge: None
# Metabolite: n4abutn_c, Formula: C6H11NO2, Charge: 0
# Metabolite: n6hxlys_c, Formula: C6H14N2O3, Charge: 0
# Metabolite: nacitrul__L_c, Formula: C8H15N3O4, Charge: 0
# Metabolite: nacpphin_c, Formula: C7H14NO5P, Charge: 0
# Metabolite: nadhx__R_c, Formula: C21H31N7O15P2, Charge: 0
# Metabolite: nadhx__S_c, Formula: C21H31N7O15P2, Charge: 0
# Metabolite: nadphx__R_c, Formula: C21H32N7O18P3, Charge: 0
# Metabolite: nadphx__S_c, Formula: C21H32N7O18P3, Charge: 0
# Metabolite: nal2a6o_c, Formula: C9H11NO6, Charge: -2
# Failed to retrieve data for all-transneurosporene
# Metabolite: neuspn_c, Formula: None, Charge: None
# Metabolite: nic1ox_c, Formula: C10H14N2O, Charge: 0
# Metabolite: nico__S_c, Formula: C10H14N2, Charge: 0
# Metabolite: nisirhcl_c, Formula: C42H36N4NiO16, Charge: -10
# Metabolite: nndmyani_c, Formula: C8H11N, Charge: 0
# Metabolite: nphtatt_c, Formula: C10H8O4, Charge: 0
# Failed to retrieve data for Ni-sirohydrochlorina,c-diamide
# Metabolite: nsirhcda_c, Formula: None, Charge: None
# Metabolite: orn__D_c, Formula: C5H12N2O2, Charge: 0
# Metabolite: p_tol_c, Formula: C8H7O2, Charge: -1
# Metabolite: paolac_c, Formula: C15H16O5, Charge: 0
# Failed to retrieve data for p-cumicaldehyde
# Metabolite: pcumald_c, Formula: None, Charge: None
# Metabolite: pcumat_c, Formula: C10H11O2, Charge: -1
# Failed to retrieve data for pentalenolactoneF
# Metabolite: pentlacF_c, Formula: None, Charge: None
# Failed to retrieve data for pentalenolactoneD
# Metabolite: pentlacd_c, Formula: None, Charge: None
# Metabolite: phitcoa_c, Formula: C32H44N7O19P3S, Charge: 0
# Failed to retrieve data for L-1-PHOSPHATIDYL-ETHANOLAMINE
# Metabolite: ppdyletamin_c, Formula: None, Charge: None
# Metabolite: pphinit_c, Formula: C5H12NO4P, Charge: 0
# Metabolite: pppn_c, Formula: C9H9O2, Charge: -1
# Metabolite: pre1_c, Formula: C41H46N4O16, Charge: 0
# Failed to retrieve data for prephytoenediphosphate
# Metabolite: prephytedp_c, Formula: None, Charge: None
# Metabolite: pro__D_c, Formula: C5H9NO2, Charge: 0
# Metabolite: prp13da_c, Formula: C3H10N2, Charge: 0
# Metabolite: prp2enoate_c, Formula: C9H9O4, Charge: -1
# Metabolite: prpncoa_c, Formula: C24H38N7O17P3S, Charge: 0
# Metabolite: psqldi_c, Formula: C30H52O7P2, Charge: 0
# Failed to retrieve data for pseudouridine5'-phosphate
# Metabolite: puri4pp_c, Formula: None, Charge: None
# Metabolite: pyr2cbox_c, Formula: C5H6NO2, Charge: -1
# Metabolite: pyrgal_c, Formula: C6H6O3, Charge: 0
# Metabolite: rib1mpp5tpp_c, Formula: C6H11O16P4, Charge: -5
# Failed to retrieve data for D-ribulose1-phosphate
# Metabolite: ru1p__D_c, Formula: None, Charge: None
# Metabolite: sbt6p_c, Formula: C6H15O9P, Charge: 0
# Metabolite: sl__L_c, Formula: C3H4O6S, Charge: -2
# Failed to retrieve data for L-sorbosone1,4-lactone
# Metabolite: sorb14lac_c, Formula: None, Charge: None
# Metabolite: stmyn_c, Formula: C21H39N7O12, Charge: 0
# Failed to retrieve data for streptomycin6-phosphate
# Metabolite: strep6p_c, Formula: None, Charge: None
# Metabolite: tbutalc_c, Formula: C4H10O, Charge: 0
# Metabolite: tbutfor_c, Formula: C5H9O2, Charge: -1
# Metabolite: tbutmet_c, Formula: C5H12O2, Charge: 0
# Metabolite: tcl14bzq_c, Formula: C6Cl4O2, Charge: 0
# Metabolite: tclhqn_c, Formula: C6H2Cl4O2, Charge: 0
# Metabolite: tcynt_c, Formula: CNS, Charge: -1
# Metabolite: tma_c, Formula: C3H9N, Charge: 0
# Failed to retrieve data for trimethylamineN-oxide
# Metabolite: tmao_c, Formula: None, Charge: None
# Metabolite: todcpribfur_c, Formula: C55H91O8P, Charge: 0
# Metabolite: tsul_c, Formula: O3S2, Charge: -2
# Metabolite: uGgl_c, Formula: C34H52N7O24P2, Charge: -3
# Metabolite: uGgla_c, Formula: C40H65N9O26P2, Charge: 0
# Metabolite: unaga_c, Formula: C63H103NO12P2, Charge: -2
# Metabolite: vanln_c, Formula: C8H8O3, Charge: 0
# Metabolite: xyhex3u14lac_c, Formula: C6H8O6, Charge: 0
# Metabolite: zcarote_c, Formula: C40H60, Charge: 0
# Failed to retrieve data for biomass
# Metabolite: biomass_c, Formula: None, Charge: None
# Failed to retrieve data for beta-D-glucopyranose1-phosphate
# Metabolite: g1p_B_c, Formula: None, Charge: None
# Metabolite: 23dhb_c, Formula: C7H5O4, Charge: -1
# Metabolite: Glc_aD_c, Formula: C6H12O6, Charge: 0
# Metabolite: rbl__D_c, Formula: C5H10O5, Charge: 0
# Metabolite: ethamp_c, Formula: C2H8NO4P, Charge: 0
# Metabolite: retinal_c, Formula: C20H28O, Charge: 0
# Metabolite: trypta_c, Formula: C10H12N2, Charge: 0
# Metabolite: 5aptn_c, Formula: C5H11NO2, Charge: 0
# Metabolite: retinol_c, Formula: C20H30O, Charge: 0
# Metabolite: tym_c, Formula: C8H11NO, Charge: 0
# Metabolite: rbl__L_c, Formula: C5H10O5, Charge: 0
# Metabolite: ocdce9coa_c, Formula: C39H68N7O17P3S, Charge: 0
# Metabolite: hxdcal_c, Formula: C16H32O, Charge: 0
# Metabolite: nrpphr_c, Formula: C8H11NO3, Charge: 0
# Metabolite: 3sala_c, Formula: C3H7NO4S, Charge: 0
# Metabolite: id3acald_c, Formula: C10H9NO, Charge: 0
# Metabolite: srtn_c, Formula: C10H12N2O, Charge: 0
# Metabolite: 5apentam_c, Formula: C5H12N2O, Charge: 0
# Failed to retrieve data for Ferricytochrome b5
# Metabolite: ficytb5_c, Formula: None, Charge: None
# Failed to retrieve data for Ferrocytochrome b5
# Metabolite: focytb5_c, Formula: None, Charge: None
# Metabolite: 3hpp_c, Formula: C3H5O3, Charge: -1
# Metabolite: ru5p__L_c, Formula: C5H11O8P, Charge: 0
# Metabolite: sph1p_c, Formula: C18H40NO5P, Charge: 0
# Metabolite: seln_c, Formula: H2Se, Charge: 0
# Metabolite: cbm_c, Formula: CH2NO2, Charge: -1
# Metabolite: 5oxpro_c, Formula: C5H7NO3, Charge: 0
# Metabolite: aact_c, Formula: C3H7NO, Charge: 0
# Metabolite: 2mcit_c, Formula: C7H10O7, Charge: 0
# Metabolite: fru_B_c, Formula: C6H12O6, Charge: 0
# Metabolite: C02356_c, Formula: C4H9NO2, Charge: 0
# Metabolite: pad_c, Formula: C8H9NO, Charge: 0
# Metabolite: aprut_c, Formula: C6H14N2O, Charge: 0
# Metabolite: ind3acnl_c, Formula: C10H8N2, Charge: 0
# Metabolite: dopa_c, Formula: C8H11NO2, Charge: 0
# Metabolite: 4hoxpacd_c, Formula: C8H8O2, Charge: 0
# Metabolite: 34dhpac_c, Formula: C8H8O3, Charge: 0
# Metabolite: 23ddhb_c, Formula: C7H8O4, Charge: 0
# Metabolite: 2mcacn_c, Formula: C7H5O6, Charge: -3
# Metabolite: micit_c, Formula: C7H7O7, Charge: -3
# Metabolite: 2ahethmpp_c, Formula: C14H23N4O8P2S+, Charge: 1
# Metabolite: selnp_c, Formula: H3O3PSe, Charge: 0
# Metabolite: peamn_c, Formula: C8H11N, Charge: 0
# Metabolite: 34dhoxpeg_c, Formula: C8H10O4, Charge: 0
# Metabolite: 34dhmald_c, Formula: C8H8O4, Charge: 0
# Metabolite: 3mox4hpac_c, Formula: C9H10O3, Charge: 0
# Metabolite: 3moxtyr_c, Formula: C9H13NO2, Charge: 0
# Metabolite: 5hoxindact_c, Formula: C10H9NO2, Charge: 0
# Metabolite: 3hxkynam_c, Formula: C9H12N2O2, Charge: 0
# Metabolite: 48dhoxquin_c, Formula: C9H7NO2, Charge: 0
# Metabolite: slnt_c, Formula: O3Se, Charge: -2
# Metabolite: aprop_c, Formula: C3H6N2, Charge: 0
# Metabolite: acybut_c, Formula: C5H8N2O2, Charge: 0
# Metabolite: 2coum_c, Formula: C9H8O3, Charge: 0
# Metabolite: bdg2hc_c, Formula: C15H18O8, Charge: 0
# Metabolite: uaaGgla_c, Formula: C94H156N8O26P2, Charge: 0
# Metabolite: uaaGgtla_c, Formula: C94H157N9O25P2, Charge: 0
# Metabolite: 3hivcoa_c, Formula: C26H44N7O18P3S, Charge: 0
# Metabolite: 3hib_c, Formula: C4H7O3, Charge: -1
# Metabolite: adphep_DD_c, Formula: C17H27N5O16P2, Charge: 0
# Metabolite: 3hpimcoa_c, Formula: C28H46N7O20P3S, Charge: 0
# Metabolite: 3opimcoa_c, Formula: C28H44N7O20P3S, Charge: 0
# Metabolite: hmccm_c, Formula: C7H8O5, Charge: 0
# Metabolite: 2omcm_c, Formula: C7H8O5, Charge: 0
# Metabolite: gmhep1p_c, Formula: C7H13O10P, Charge: -2
# Metabolite: so2_c, Formula: O2S, Charge: 0
# Metabolite: mso3_c, Formula: CH4O3S, Charge: 0
# Metabolite: CE1944_c, Formula: C4H7N, Charge: 0
# Metabolite: ddmcital_c, Formula: C18H17FN2O, Charge: 0
# Metabolite: citalald_c, Formula: C18H14FNO2, Charge: 0
# Metabolite: 6txan5mp_c, Formula: C10H13N4O8PS, Charge: 0
# Metabolite: 6tgsnmp_c, Formula: C10H14N5O7PS, Charge: 0
# Metabolite: suc6p_c, Formula: C12H23O14P, Charge: 0
# Metabolite: dgslnt_c, Formula: C20H32N6O12S2Se, Charge: 0
# Metabolite: 2plac__L_c, Formula: C3H4O6P, Charge: -3
# Metabolite: 34dhbz_c, Formula: C7H5O4, Charge: -1
# Metabolite: lcts_c, Formula: C12H22O11, Charge: 0
# Metabolite: gam_c, Formula: C6H13NO5, Charge: 0
# Metabolite: rbt_c, Formula: C5H12O5, Charge: 0
# Metabolite: op4en_c, Formula: C5H5O3, Charge: -1
# Metabolite: galctn__D_c, Formula: C6H11O7, Charge: -1
# Metabolite: btal_c, Formula: C4H8O, Charge: 0
# Metabolite: bgly_c, Formula: C9H9NO3, Charge: 0
# Metabolite: hkndd_c, Formula: C9H10O6, Charge: 0
# Metabolite: hkntd_c, Formula: C9H8O6, Charge: 0
# Failed to retrieve data for 2-carboxy-3-amino-6-hydroxy-1,4-dihydroquinone, 6-allose
# Metabolite: m_0007, Formula: None, Charge: None
# Failed to retrieve data for L-xylulose1-phosphate
# Metabolite: xu1p__D_c, Formula: None, Charge: None
# Failed to retrieve data for (E)-2-methylgeranyldiphosphate
# Metabolite: 2mygydpp_c, Formula: None, Charge: None
# Metabolite: 2mborn_c, Formula: C11H20O, Charge: 0

# %%
import requests
from bs4 import BeautifulSoup

def get_metanetx_formula(metanetx_id):
    # Construct the URL using the MetaNetX ID
    url = f"https://www.metanetx.org/chem_info/{metanetx_id}"

    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise error for bad status codes
        
        # Parse HTML content
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Locate the table cell containing the formula
        formula_header = soup.find('td', string='formula')
        
        if formula_header:
            formula_cell = formula_header.find_next_sibling('td')
            if formula_cell:
                formula = formula_cell.text.strip("* ")
        
        # Locate the table cell containing the formula
        charge_header = soup.find('td', string='charge')
        
        if charge_header:
            charge_cell = charge_header.find_next_sibling('td')
            if charge_cell:
                if charge_cell.text.strip() != '':
                    charge = int(charge_cell.text.strip())
                else:
                    charge = None

        if formula:
            return formula, charge
        print(f"Formula not found for {metanetx_id}")
        return None, None
        
    except requests.exceptions.RequestException as e:
        print(f"Request failed: {e}")
    except Exception as e:
        print(f"Error: {e}")
    return None, None

failed_again = []
for m in still_failed:
    met = model.metabolites.get_by_id(m)

    try:
        print(met, met.name)
        metanetx_id = met.annotation['metanetx.chemical']
        met.formula, met.charge = get_metanetx_formula(metanetx_id)
    except:
        failed_again.append(met.id)
        print("FAILED: ", met, met.annotation)
# Out:
# 12da3oaglcpyr_c 12-DIACYL-3-O-ALPHA-D-GLUCOPYRANOSYL
# 2dh3dgal6p_c 2-dehydro-3-deoxy-D-galactonate6-phosphate
# 2mop_c CPD-12179
# 3hcinnm_c 3-hydroxy-trans-cinnamate
# 44dpcop_c 4,4'-diapolycopenedial
# 5cmhmsa_c 2-hydroxy-5-carboxymethylmuconatesemialdehyde
# ETFred_c ETF-Reduced
# agdppdtundec_c beta-D-GlcA-(1rarr2)-alpha-D-Man-(1rarr3)-beta-D-Glc-(1rarr4)-alpha-D-Glc-1-diphospho-ditrans,octacis-undecaprenol
# FAILED:  agdppdtundec_c {'sbo': 'SBO:0000247', 'pubchem.compound': '52940195', 'smiles': 'SMILES:CC=C(CCC=C(CCC=C(CCC=C(CCC=C(C)CCC=C(CCC=C(CCC=C(CCC=C(C)CCC=C(C)CCC=C(C)COP(=O)([O-])OP(=O)([O-])OC4(OC(CO)C(OC3(OC(CO)C(O)C(OC2(OC(CO)C(O)C(O)C(OC1(OC(C([O-])=O)C(O)C(O)C(O)1))2))C(O)3))C(O)C(O)4))C)C)C)C)C)C)C', 'origin': 'Sco4', 'biocyc': 'CPD-12771', 'bigg.metabolite': 'agdppdtundec', 'inchi': 'InChI=1S/C79H130O28P2/c1-13-48(2)24-14-25-49(3)26-15-27-50(4)28-16-29-51(5)30-17-31-52(6)32-18-33-53(7)34-19-35-54(8)36-20-37-55(9)38-21-39-56(10)40-22-41-57(11)42-23-43-58(12)47-98-108(94,95)107-109(96,97)106-78-69(90)67(88)71(61(46-82)101-78)102-77-70(91)72(63(84)60(45-81)99-77)103-79-74(65(86)62(83)59(44-80)100-79)105-76-68(89)64(85)66(87)73(104-76)75(92)93/h13,25,27,29,31,33,35,37,39,41,43,59-74,76-91H,14-24,26,28,30,32,34,36,38,40,42,44-47H2,1-12H3,(H,92,93)(H,94,95)(H,96,97)/p-3/b48-13-,49-25-,50-27-,51-29-,52-31-,53-33-,54-35-,55-37-,56-39+,57-41+,58-43+/t59-,60-,61-,62-,63-,64+,65+,66+,67-,68-,69-,70-,71-,72+,73+,74+,76+,77+,78-,79-/m1/s1'}
# ap4a_c 5',5'''-diadenosinetetraphosphate
# at44dcop_c all-trans-4,4'-diapolycopene
# atphyflu_c all-transphytofluene
# dhiconf_c (-)-dehydrodiconiferylacid
# dhiconfa_c (-)-dehydrodiconiferylaldehyde
# dolichol_c DOLICHOLP
# Request failed: 403 Client Error: Forbidden for url: https://www.metanetx.org/chem_info/%5B'MNXM278',%20'MNXM797'%5D
# dolmanp_c Dolichyl phosphate D-mannose
# etf_ox_c ETF-Oxidized
# fc1p_c L-fuculose1-phosphate
# feroxG1_c desferrioxamineG1
# formhop_c formylhopane
# frdp_2_c (2Z,6E)-farnesyldiphosphate
# fruur_c FRUCTURONATE
# gcgguaiac_c (-)-(alphaS,betaR)-guaiacylglycerol-beta-guaiacylether
# gcgguaiace_c (+)-(alphaS,betaS)-guaiacylglycerol-beta-guaiacylether
# ggcysto_c gamma-L-glutamyl-S-(hercyn-2-yl)-L-cysteineS-oxide
# hccystox_c S-(hercyn-2-yl)-L-cysteineS-oxide
# hmmsh_c S-hydroxymethylmycothiol
# kdo2laur_c alpha-Kdo-(2->4)-alpha-Kdo-(2->6)-(lauroyl)-lipidIVA
# kdo2lipid4_c alpha-Kdo-(2->4)-alpha-Kdo-(2->6)-lipidIVA
# metbute_c methyltert-butylether
# mycthigpyrpp_c mycothiol-arsenateconjugate
# neuspn_c all-transneurosporene
# nsirhcda_c Ni-sirohydrochlorina,c-diamide
# pcumald_c p-cumicaldehyde
# pentlacF_c pentalenolactoneF
# pentlacd_c pentalenolactoneD
# ppdyletamin_c L-1-PHOSPHATIDYL-ETHANOLAMINE
# prephytedp_c prephytoenediphosphate
# puri4pp_c pseudouridine5'-phosphate
# ru1p__D_c D-ribulose1-phosphate
# sorb14lac_c L-sorbosone1,4-lactone
# strep6p_c streptomycin6-phosphate
# tmao_c trimethylamineN-oxide
# biomass_c biomass
# FAILED:  biomass_c {'sbo': 'SBO:0000247'}
# g1p_B_c beta-D-glucopyranose1-phosphate
# ficytb5_c Ferricytochrome b5
# FAILED:  ficytb5_c {'sbo': 'SBO:0000247', 'kegg.compound': 'C00996', 'pubchem.substance': '4242', 'chebi': 'CHEBI:18097'}
# focytb5_c Ferrocytochrome b5
# FAILED:  focytb5_c {'sbo': 'SBO:0000247', 'kegg.compound': 'C00999', 'pubchem.substance': '4245'}
# m_0007 2-carboxy-3-amino-6-hydroxy-1,4-dihydroquinone, 6-allose
# FAILED:  m_0007 {'sbo': 'SBO:0000247'}
# xu1p__D_c L-xylulose1-phosphate
# 2mygydpp_c (E)-2-methylgeranyldiphosphate

# %%
for m in model.metabolites:
    if m.formula == None:
        print(m, m.name, m.annotation)
# Out:
# agdppdtundec_c beta-D-GlcA-(1rarr2)-alpha-D-Man-(1rarr3)-beta-D-Glc-(1rarr4)-alpha-D-Glc-1-diphospho-ditrans,octacis-undecaprenol {'sbo': 'SBO:0000247', 'pubchem.compound': '52940195', 'smiles': 'SMILES:CC=C(CCC=C(CCC=C(CCC=C(CCC=C(C)CCC=C(CCC=C(CCC=C(CCC=C(C)CCC=C(C)CCC=C(C)COP(=O)([O-])OP(=O)([O-])OC4(OC(CO)C(OC3(OC(CO)C(O)C(OC2(OC(CO)C(O)C(O)C(OC1(OC(C([O-])=O)C(O)C(O)C(O)1))2))C(O)3))C(O)C(O)4))C)C)C)C)C)C)C', 'origin': 'Sco4', 'biocyc': 'CPD-12771', 'bigg.metabolite': 'agdppdtundec', 'inchi': 'InChI=1S/C79H130O28P2/c1-13-48(2)24-14-25-49(3)26-15-27-50(4)28-16-29-51(5)30-17-31-52(6)32-18-33-53(7)34-19-35-54(8)36-20-37-55(9)38-21-39-56(10)40-22-41-57(11)42-23-43-58(12)47-98-108(94,95)107-109(96,97)106-78-69(90)67(88)71(61(46-82)101-78)102-77-70(91)72(63(84)60(45-81)99-77)103-79-74(65(86)62(83)59(44-80)100-79)105-76-68(89)64(85)66(87)73(104-76)75(92)93/h13,25,27,29,31,33,35,37,39,41,43,59-74,76-91H,14-24,26,28,30,32,34,36,38,40,42,44-47H2,1-12H3,(H,92,93)(H,94,95)(H,96,97)/p-3/b48-13-,49-25-,50-27-,51-29-,52-31-,53-33-,54-35-,55-37-,56-39+,57-41+,58-43+/t59-,60-,61-,62-,63-,64+,65+,66+,67-,68-,69-,70-,71-,72+,73+,74+,76+,77+,78-,79-/m1/s1'}
# dolichol_c DOLICHOLP {'sbo': 'SBO:0000247', 'origin': 'Sco4', 'biocyc': 'DOLICHOLP', 'kegg.compound': 'C00110', 'metanetx.chemical': ['MNXM278', 'MNXM797'], 'bigg.metabolite': 'dolichol', 'chebi': ['CHEBI:16214', 'CHEBI:57683', 'CHEBI:16091']}
# biomass_c biomass {'sbo': 'SBO:0000247'}
# ficytb5_c Ferricytochrome b5 {'sbo': 'SBO:0000247', 'kegg.compound': 'C00996', 'pubchem.substance': '4242', 'chebi': 'CHEBI:18097'}
# focytb5_c Ferrocytochrome b5 {'sbo': 'SBO:0000247', 'kegg.compound': 'C00999', 'pubchem.substance': '4245'}
# m_0007 2-carboxy-3-amino-6-hydroxy-1,4-dihydroquinone, 6-allose {'sbo': 'SBO:0000247'}

# %%
model.metabolites.get_by_id("agdppdtundec_c").formula = 'C79H127O28P2'
model.metabolites.get_by_id("agdppdtundec_c").charge = -3

model.metabolites.get_by_id("dolichol_c").formula = 'C25H44O'
model.metabolites.get_by_id("dolichol_c").charge = 0

model.metabolites.get_by_id("ficytb5_c").formula = 'C34H30FeN4O4'
model.metabolites.get_by_id("focytb5_c").formula = 'C34H30FeN4O4'

# %% [markdown]
# # 3. Check if reactions are balanced using BIGG and METANETX

# %%
imbalanced_reactions = []

# Iterate through each reaction in the model
for reaction in model.reactions:
    try:
        imbalance = reaction.check_mass_balance()
    except Exception as e:
        print(f"Error checking mass balance for {reaction.id}: {e}")
        imbalance = None
    if imbalance and not (reaction.id.startswith('EX_') or reaction.id.startswith('DM_') or 'PSEUDO' in reaction.id):
        imbalanced_reactions.append((reaction, imbalance))

# Print out the imbalanced reactions
for reaction, imbalance in imbalanced_reactions:
    print(f"Reaction: {reaction.id}, Imbalance: {imbalance}")

# Save the list of imbalanced reactions and their imbalances to a file
try:
    with open('imbalanced_reactions.txt', 'w', encoding='utf-8') as f:
        for reaction, imbalance in imbalanced_reactions:
            try:
                rxn_str = reaction.build_reaction_string()
            except Exception as e:
                rxn_str = f"Error building reaction string: {e}"
            f.write(f"Reaction: {reaction.id}\t{rxn_str}\tImbalance: {imbalance}\n")
    print("imbalanced_reactions.txt written successfully.")
except Exception as e:
    print(f"Failed to write imbalanced_reactions.txt: {e}")
# Out:
# Error checking mass balance for GLNTRAT: No elements found in metabolite glutrna_gln_c
# Error checking mass balance for ASNTRAT: No elements found in metabolite asptrna_asn_c
# Error checking mass balance for DMT: No elements found in metabolite dnac_c
# Error checking mass balance for SELCYSS: No elements found in metabolite sertrna_sec_c
# Reaction: 3OCHOCDH, Imbalance: {'charge': -1.0, 'H': -1.0}
# Reaction: 3OXCOADH, Imbalance: {'charge': -5.0, 'H': -5.0}
# Reaction: 4SBZADH, Imbalance: {'charge': 1.0, 'H': 1.0}
# Reaction: ACPSpdscpk, Imbalance: {'charge': -1.0}
# Reaction: AHMMPS, Imbalance: {'charge': -2.0}
# Reaction: AHOPS, Imbalance: {'charge': 1.0, 'H': 1.0}
# Reaction: AMBACS, Imbalance: {'charge': -1.0, 'H': -1.0}
# Reaction: ASR, Imbalance: {'charge': -1.0, 'H': -1.0}
# Reaction: BCOADH, Imbalance: {'charge': 1.0}
# Reaction: BSUZCOAD, Imbalance: {'charge': -6.0, 'H': -5.0}
# Reaction: CARBMODH, Imbalance: {'H': -2.0}
# Reaction: CMCMSAD, Imbalance: {'charge': 3.0, 'H': 3.0}
# Reaction: CPKS1, Imbalance: {'charge': -6.0}
# Reaction: CPKS2, Imbalance: {'charge': -2.0}
# Reaction: CPKS3, Imbalance: {'charge': -1.0}
# Reaction: CYANST, Imbalance: {'charge': 1.0, 'H': 1.0}
# Reaction: CYCOADH, Imbalance: {'charge': -1.0}
# Reaction: CYO1ab, Imbalance: {'charge': -2.0, 'H': -2.0}
# Reaction: CYO2b, Imbalance: {'charge': 2.0, 'H': 2.0}
# Reaction: CYSBLY, Imbalance: {'charge': 1.0, 'H': 1.0}
# Reaction: DABAACT, Imbalance: {'charge': -1.0, 'H': -1.0}
# Reaction: DABAAT, Imbalance: {'charge': -1.0, 'H': -1.0}
# Reaction: DDALLO, Imbalance: {'charge': 1.0, 'H': 1.0}
# Reaction: DPCOX, Imbalance: {'charge': 4.0, 'H': 4.0}
# Reaction: FMNAT, Imbalance: {'charge': -2.0, 'H': -2.0}
# Reaction: FMNRx, Imbalance: {'charge': -2.0, 'H': -2.0}
# Reaction: FMNRx2, Imbalance: {'charge': -2.0, 'H': -2.0}
# Reaction: G6PBDH, Imbalance: {'charge': -2.0, 'H': -2.0}
# Reaction: G6PDH1b, Imbalance: {'charge': -2.0, 'H': -2.0}
# Reaction: G6PI, Imbalance: {'charge': 2.0, 'H': 2.0}
# Reaction: GLUKB, Imbalance: {'charge': 2.0, 'H': 2.0}
# Reaction: GUL5DH, Imbalance: {'charge': 1.0, 'H': 1.0}
# Reaction: HCSUCT, Imbalance: {'charge': 1.0, 'H': 1.0}
# Reaction: HPHL, Imbalance: {'charge': -4.0, 'H': -4.0}
# Reaction: IZPN, Imbalance: {'charge': 1.0, 'H': 1.0}
# Reaction: MMYSYN1, Imbalance: {'charge': -1.0, 'H': 1.0}
# Reaction: MPML, Imbalance: {'charge': 2.0, 'H': 2.0}
# Reaction: MSUCOADH, Imbalance: {'charge': -1.0}
# Reaction: NADPHQR4, Imbalance: {'charge': 1.0, 'H': 1.0}
# Reaction: NICMO, Imbalance: {'charge': 1.0, 'H': 1.0}
# Reaction: NSHDDS, Imbalance: {'charge': 2.0}
# Reaction: PCFO, Imbalance: {'charge': -4.0, 'H': -4.0}
# Reaction: PHYFLUDS, Imbalance: {'charge': -1.0, 'H': -1.0}
# Reaction: PHYTDES, Imbalance: {'charge': -1.0, 'H': -1.0}
# Reaction: PPTRIAT, Imbalance: {'charge': 1.0, 'H': 1.0}
# Reaction: PSD181, Imbalance: {'charge': 1.0, 'H': 1.0}
# Reaction: PSSA181, Imbalance: {'charge': -1.0, 'H': -1.0}
# Reaction: RBFK, Imbalance: {'charge': 2.0, 'H': 2.0}
# Reaction: S6PGB, Imbalance: {'charge': 2.0, 'H': 2.0}
# Reaction: SCB15, Imbalance: {'O': -1.0}
# Reaction: SCB35, Imbalance: {'O': -1.0}
# Reaction: SORBDH, Imbalance: {'charge': -1.0, 'H': -1.0}
# Reaction: SUCOAICT, Imbalance: {'charge': 3.0, 'H': 3.0}
# Reaction: TMDSf, Imbalance: {'charge': 2.0, 'H': 2.0}
# Reaction: ZCARDS, Imbalance: {'charge': -1.0, 'H': -1.0}
# Reaction: ZCAROTDH2, Imbalance: {'charge': 1.0, 'H': 1.0}
# Reaction: CELLUL_DEGe, Imbalance: {'H': -500.0, 'O': -250.0}
# Reaction: CYO2a, Imbalance: {'charge': -2.0, 'H': -2.0}
# Reaction: FeHemu, Imbalance: {'charge': -5.0, 'H': -3.0, 'O': 1.0}
# Reaction: HISpep, Imbalance: {'charge': 2.0, 'C': 1.0, 'N': 1.0, 'O': -3.0, 'P': -1.0, 'R': 2.0}
# Reaction: BIOMASS_SALB, Imbalance: {'R': -7.0}
# Reaction: NADH8, Imbalance: {'charge': 1.0, 'H': 1.0}
# Reaction: TECA1S, Imbalance: {'charge': 25.0}
# Reaction: DNMPPA, Imbalance: {'charge': -1.0}
# Reaction: DNTPPA_1, Imbalance: {'charge': 1.0}
# Reaction: FRD3, Imbalance: {'charge': -1.0, 'H': -1.0}
# Reaction: TRE6PPP, Imbalance: {'charge': 2.0, 'H': 2.0}
# Reaction: PDE1, Imbalance: {'charge': -1.0, 'H': -1.0}
# Reaction: PDH, Imbalance: {'charge': 1.0, 'H': 1.0}
# Reaction: OPAH, Imbalance: {'charge': -2.0, 'H': -2.0}
# Reaction: ASP4DC, Imbalance: {'charge': 1.0, 'H': 1.0}
# Reaction: PTRCAT1, Imbalance: {'charge': -2.0, 'H': -2.0}
# Reaction: P5CRx, Imbalance: {'charge': 1.0, 'H': 1.0}
# Reaction: DHBD, Imbalance: {'charge': -1.0, 'H': -1.0}
# Reaction: RBK_Dr, Imbalance: {'charge': -1.0, 'H': -1.0}
# Reaction: GUAD, Imbalance: {'charge': 1.0, 'H': 1.0}
# Reaction: GLUKA, Imbalance: {'charge': -1.0, 'H': -1.0}
# Reaction: AHAL, Imbalance: {'charge': -3.0, 'H': -3.0}
# Reaction: TRYPTAOX, Imbalance: {'charge': 1.0, 'H': 1.0}
# Reaction: COA1819ZD9DS, Imbalance: {'charge': 2.0, 'H': 4.0}
# Reaction: APENTAMAH, Imbalance: {'charge': 1.0, 'H': 1.0}
# Reaction: G1PTT, Imbalance: {'charge': 1.0, 'H': 1.0}
# Reaction: TYROXDAc, Imbalance: {'charge': 1.0, 'H': 1.0}
# Reaction: RBK_L1, Imbalance: {'charge': 1.0, 'H': 1.0}
# Reaction: AACTOOR, Imbalance: {'charge': 1.0, 'H': 1.0}
# Reaction: 41R2A1H12BOOX, Imbalance: {'charge': 1.0, 'H': 1.0}
# Reaction: PEAMNO, Imbalance: {'charge': 1.0, 'H': 1.0}
# Reaction: 5HOXINOXDA, Imbalance: {'charge': 1.0, 'H': 1.0}
# Reaction: HPROa, Imbalance: {'charge': 1.0, 'H': 1.0}
# Reaction: NTRLASE2, Imbalance: {'charge': 1.0, 'H': 1.0}
# Reaction: FFSD, Imbalance: {'charge': -2.0, 'H': -2.0}
# Reaction: APRTO2, Imbalance: {'charge': 1.0, 'H': 1.0}
# Reaction: ECH_3hivcoa, Imbalance: {'charge': -4.0, 'H': -4.0}
# Reaction: 42A12BOOX, Imbalance: {'charge': 1.0, 'H': 1.0}
# Reaction: MCITD, Imbalance: {'charge': -3.0, 'H': -3.0}
# Reaction: ACAS_2ahbut, Imbalance: {'charge': -3.0, 'H': -3.0}
# Reaction: AHSERL4, Imbalance: {'charge': -3.0, 'H': -3.0}
# Reaction: 3MOXTYROX, Imbalance: {'charge': 1.0, 'H': 1.0}
# Reaction: 3HXKYNOXDA, Imbalance: {'charge': 1.0, 'H': 1.0}
# Reaction: GLNSP2, Imbalance: {'charge': -2.0, 'H': -2.0}
# Reaction: GMHEPAT, Imbalance: {'charge': 3.0, 'H': 3.0}
# Reaction: RBP4E, Imbalance: {'charge': -2.0, 'H': -2.0}
# Reaction: 6TXAN5MPAML, Imbalance: {'charge': -2.0, 'H': -2.0}
# Reaction: DDMCITALOR, Imbalance: {'charge': 1.0, 'H': 1.0}
# Reaction: LPPGS, Imbalance: {'charge': 2.0, 'H': 2.0}
# Reaction: KAS15, Imbalance: {'charge': 1.0, 'H': 1.0}
# Reaction: CBMD, Imbalance: {'charge': 2.0, 'H': 2.0}
# Reaction: RE0691C, Imbalance: {'charge': -1.0, 'H': -1.0}
# Reaction: SELGTHR, Imbalance: {'charge': 2.0, 'H': 2.0}
# Reaction: MCITS, Imbalance: {'charge': -2.0, 'H': -2.0}
# Reaction: GALO, Imbalance: {'charge': -1.0, 'H': -1.0}
# Reaction: NBAH, Imbalance: {'charge': -1.0, 'H': -1.0}
# Reaction: HKNDDH, Imbalance: {'charge': 3.0, 'H': 3.0}
# Reaction: PGMT_B, Imbalance: {'charge': 2.0, 'H': 2.0}
# Reaction: ICHORT, Imbalance: {'charge': 1.0, 'H': 1.0}
# Reaction: 3HPCOAHYD, Imbalance: {'charge': 1.0, 'H': 1.0}
# Reaction: HIBH, Imbalance: {'charge': -1.0, 'H': -1.0}
# Reaction: HKNTDH, Imbalance: {'charge': -3.0, 'H': -3.0}
# Reaction: r_0001, Imbalance: {'charge': 2.0, 'H': 2.0}
# Reaction: r_0002, Imbalance: {'charge': -1.0, 'H': -1.0}
# Reaction: r_0003, Imbalance: {'H': -1.0}
# Reaction: r_0004, Imbalance: {'charge': 1.0, 'H': -2.0}
# Reaction: r_0005, Imbalance: {'charge': 2.0, 'H': 3.0}
# Reaction: r_0006, Imbalance: {'charge': 2.0, 'C': -16.0, 'H': -24.0, 'N': -2.0, 'O': -16.0, 'P': -2.0}
# Reaction: r_0007, Imbalance: {'charge': -3.0, 'C': 3.0, 'H': 5.0, 'N': 1.0, 'O': 6.0, 'P': 2.0}
# Reaction: r_0011, Imbalance: {'charge': -1.0, 'H': -1.0}
# Reaction: r_0012, Imbalance: {'charge': -3.0, 'C': 2.0, 'H': 5.0, 'N': 5.0, 'O': 1.0, 'P': 1.0, 'S': 1.0}
# Reaction: r_0014, Imbalance: {'charge': -4.0, 'C': 21.0, 'H': 32.0, 'N': 7.0, 'O': 16.0, 'P': 3.0, 'S': 1.0}
# Reaction: r_0015, Imbalance: {'charge': 4.0, 'C': -25.0, 'H': -36.0, 'N': -7.0, 'O': -17.0, 'P': -3.0, 'S': -1.0}
# Reaction: r_0016, Imbalance: {'charge': 4.0, 'C': -23.0, 'H': -34.0, 'N': -7.0, 'O': -17.0, 'P': -3.0, 'S': -1.0}
# Reaction: r_0018, Imbalance: {'charge': 4.0, 'C': -26.0, 'H': -40.0, 'N': -7.0, 'O': -17.0, 'P': -3.0, 'S': -1.0}
# Reaction: r_0019, Imbalance: {'charge': 4.0, 'C': -25.0, 'H': -38.0, 'N': -7.0, 'O': -17.0, 'P': -3.0, 'S': -1.0}
# Reaction: metylmalonyl_synthesis, Imbalance: {'charge': 5.0, 'H': 5.0}
# Reaction: ethylmalonyl_synthesis, Imbalance: {'charge': 5.0, 'H': 5.0}
# Reaction: NP1_2, Imbalance: {'charge': 1.0, 'H': 2.0, 'N': 1.0, 'O': -1.0}
# Reaction: FBA4, Imbalance: {'charge': -2.0, 'H': -2.0}
# Reaction: HMR_9726, Imbalance: {'H': 1.0, 'N': 1.0, 'O': -1.0}
# Reaction: NRRH, Imbalance: {'charge': 1.0, 'H': 2.0, 'O': -1.0, 'N': 1.0}
# Reaction: PHYCBOXL, Imbalance: {'charge': -1.0, 'H': -1.0}
# Reaction: KHK2, Imbalance: {'charge': 1.0, 'H': 1.0}
# imbalanced_reactions.txt written successfully.
# /Users/techen/biosustain/projects/strepto/streptsd/.venv/lib/python3.12/site-packages/cobra/core/metabolite.py:132: UserWarning: invalid formula (has parenthesis) in 'C20H28N6O13PR(C5H8O6PR)n'
#   warn(f"invalid formula (has parenthesis) in '{self.formula}'")
# /Users/techen/biosustain/projects/strepto/streptsd/.venv/lib/python3.12/site-packages/cobra/core/metabolite.py:132: UserWarning: invalid formula (has parenthesis) in 'C14H22NO13PR2(C5H8O6PR)n'
#   warn(f"invalid formula (has parenthesis) in '{self.formula}'")
# /Users/techen/biosustain/projects/strepto/streptsd/.venv/lib/python3.12/site-packages/cobra/core/metabolite.py:132: UserWarning: invalid formula (has parenthesis) in 'C9H14N3O7P(C5H8O5PR)n(C5H8O5PR)n'
#   warn(f"invalid formula (has parenthesis) in '{self.formula}'")
# /Users/techen/biosustain/projects/strepto/streptsd/.venv/lib/python3.12/site-packages/cobra/core/metabolite.py:132: UserWarning: invalid formula (has parenthesis) in 'C13H22NO12PR2(C5H8O6PR)n'
#   warn(f"invalid formula (has parenthesis) in '{self.formula}'")

# %%
len(imbalanced_reactions)
# Out:
# 140

# %%
import requests

exclude_metabolites = {"nadh_c", "nad_c", "h_c", "h2o_c", "o2_c", "atp_c", "adp_c", "pi_c", "coa_c", "co2_c", "nh4_c", "h2o2_c", "ppi_c", "glu__L_c", "succ_c", "accoa_c", "pyr_c", "donor_c", "acceptor_c"}

def get_metanetx_id(met):
    metanetx_id = None
    if hasattr(met, "annotation"):
        ann = met.annotation
        if "metanetx.chemical" in ann:
            metanetx_id = ann["metanetx.chemical"]
            if isinstance(metanetx_id, list):
                metanetx_id = metanetx_id[0]
    return metanetx_id

def get_bigg_formula_charge(bigg_id):
    # Remove compartment suffix (e.g., "_c")
    if bigg_id.endswith("_c") or bigg_id.endswith("_e") or bigg_id.endswith("_m") or bigg_id.endswith("_p"):
        base_id = bigg_id[:-2]
    else:
        base_id = bigg_id
    url = f"http://bigg.ucsd.edu/api/v2/universal/metabolites/{base_id}"
    try:
        resp = requests.get(url, timeout=10)
        if resp.status_code == 200:
            data = resp.json()
            formula = data.get("formula", None)
            # Try to get charge from compartments_in_models
            charge = None
            for comp in data.get("compartments_in_models", []):
                if comp.get("bigg_id", None) == bigg_id[-1]:  # match compartment
                    if "charge" in comp:
                        charge = comp["charge"]
                        break
            # If not found, try to get from top-level (rare)
            if charge is None:
                charge = data.get("charge", None)
            return formula, charge
        else:
            print(f"    BIGG API error for {base_id}: status {resp.status_code}")
            return None, None
    except Exception as e:
        print(f"    BIGG API error for {base_id}: {e}")
        return None, None

for reaction, imbalance in imbalanced_reactions:
    if set(imbalance.keys()) == {'charge', 'H'} and imbalance['charge'] == imbalance['H']:
        print(f"\nReaction {reaction.id} compounds (excluding common cofactors):")
        mets_to_check = []
        for met in reaction.metabolites:
            if met.id not in exclude_metabolites:
                print(f"  {met.id}: {met.formula}, charge={met.charge}")
                metanetx_id = get_metanetx_id(met)
                met_mnx_formula, met_mnx_charge = None, None
                if metanetx_id:
                    try:
                        met_mnx_formula, met_mnx_charge = get_metanetx_formula(metanetx_id)
                        print(f"    MetaNetX: {metanetx_id}, formula={met_mnx_formula}, charge={met_mnx_charge}")
                        if met_mnx_formula != met.formula or met_mnx_charge != met.charge:
                            print(f"    DIFFERENCE: Model formula/charge = {met.formula}/{met.charge}, MetaNetX = {met_mnx_formula}/{met_mnx_charge}")
                            mets_to_check.append((met, "metanetx", met_mnx_formula, met_mnx_charge))
                    except Exception as e:
                        print(f"    Could not retrieve MetaNetX info for {metanetx_id}: {e}")
                else:
                    print("    No MetaNetX ID found in annotation.")

                # If MetaNetX did not work or is not different, try BIGG
                bigg_formula, bigg_charge = get_bigg_formula_charge(met.id)
                if bigg_formula is not None or bigg_charge is not None:
                    if (bigg_formula != met.formula or (bigg_charge is not None and bigg_charge != met.charge)):
                        print(f"    BIGG: formula={bigg_formula}, charge={bigg_charge}")
                        print(f"    DIFFERENCE: Model formula/charge = {met.formula}/{met.charge}, BIGG = {bigg_formula}/{bigg_charge}")
                        mets_to_check.append((met, "bigg", bigg_formula, bigg_charge))

        # Try updating each possible alternative (MetaNetX, then BIGG) for each metabolite
        for met, source, new_formula, new_charge in mets_to_check:
            if new_formula is None and new_charge is None:
                continue
            old_formula = met.formula
            old_charge = met.charge
            if new_formula is not None:
                met.formula = new_formula
            if new_charge is not None:
                met.charge = new_charge
            try:
                new_imbalance = reaction.check_mass_balance()
            except Exception as e:
                print(f"    Error checking mass balance after update: {e}")
                new_imbalance = None
            if not new_imbalance:
                print(f"\n  Updating {met.id} to {source} formula/charge would balance reaction {reaction.id}!")
                user_input = input(f"    Update {met.id} in the model to formula={new_formula}, charge={new_charge}? (y/n): ")
                if user_input.strip().lower() == "y":
                    print(f"    Updated {met.id} in the model.")
                else:
                    # Revert to old values
                    met.formula = old_formula
                    met.charge = old_charge
                    print(f"    Did not update {met.id}.")
            else:
                # Revert to old values
                met.formula = old_formula
                met.charge = old_charge
# Out:
# Reaction 3OCHOCDH compounds (excluding common cofactors):
#   3oce26ocoa_c: C48H72N7O18P3S, charge=-4
#     MetaNetX: MNXM8127, formula=C48H72N7O18P3S, charge=-4
#     BIGG API error for 3oce26ocoa: status 404
#   3ocd26ocoa_c: C48H70N7O18P3S, charge=-4
#     MetaNetX: MNXM8126, formula=C48H70N7O18P3S, charge=-4
#     BIGG API error for 3ocd26ocoa: status 404
#
# Reaction 3OXCOADH compounds (excluding common cofactors):
#   3oc4en24ocoa_c: C45H70N7O18P3S, charge=0
#     MetaNetX: MNXM10109, formula=C45H66N7O18P3S, charge=-4
#     DIFFERENCE: Model formula/charge = C45H70N7O18P3S/0, MetaNetX = C45H66N7O18P3S/-4
#     BIGG API error for 3oc4en24ocoa: status 404
#   3ocdncoa_c: C45H64N7O18P3S, charge=-4
#     MetaNetX: MNXM10108, formula=C45H64N7O18P3S, charge=-4
#     BIGG API error for 3ocdncoa: status 404
#
# Reaction 4SBZADH compounds (excluding common cofactors):
#   4sulbza_c: C7H6O4S, charge=0
#     MetaNetX: MNXM2194, formula=C7H5O4S, charge=-1
#     DIFFERENCE: Model formula/charge = C7H6O4S/0, MetaNetX = C7H5O4S/-1
#     BIGG API error for 4sulbza: status 404
#   4sulfbenz_c: C7H6O5S, charge=0
#     MetaNetX: MNXM2088, formula=C7H4O5S, charge=-2
#     DIFFERENCE: Model formula/charge = C7H6O5S/0, MetaNetX = C7H4O5S/-2
#     BIGG API error for 4sulfbenz: status 404
#
# Reaction AHOPS compounds (excluding common cofactors):
#   amet_c: C15H23N6O5S, charge=1
#     MetaNetX: MNXM16, formula=C15H23N6O5S, charge=1
#   hop22en_c: C30H50, charge=0
#     MetaNetX: MNXM4615, formula=C30H50, charge=0
#     BIGG API error for hop22en: status 404
#   ahop_c: C40H63N5O3, charge=0
#     MetaNetX: MNXM97442, formula=C40H63N5O3, charge=0
#   met__L_c: C5H11NO2S, charge=0
#     MetaNetX: MNXM61, formula=C5H11NO2S, charge=0
#
# Reaction AMBACS compounds (excluding common cofactors):
#   formhop_c: C35H60O4, charge=0
#     MetaNetX: MNXM97325, formula=C35H60O4, charge=0
#     BIGG API error for formhop: status 404
#   abacptri_c: C35H63NO3, charge=0
#     MetaNetX: MNXM36845, formula=C35H63NO3, charge=0
#     BIGG API error for abacptri: status 404
#   akg_c: C5H4O5, charge=-2
#     MetaNetX: MNXM20, formula=C5H4O5, charge=-2
#
# Reaction ASR compounds (excluding common cofactors):
#   aso4_c: HAsO4, charge=-2
#     MetaNetX: MNXM970, formula=HAsO4, charge=-2
#   msh_c: C17H30N2O12S, charge=0
#     MetaNetX: MNXM114216, formula=C17H30N2O12S, charge=0
#   aso3_c: AsO3, charge=-3
#     MetaNetX: MNXM658, formula=AsO3, charge=-3
#   mssg_c: C34H58N4O24S2, charge=0
#     MetaNetX: MNXM12305, formula= , charge=None
#     DIFFERENCE: Model formula/charge = C34H58N4O24S2/0, MetaNetX =  /None
#
# Reaction CMCMSAD compounds (excluding common cofactors):
#   5cmhmsa_c: C8H6O6, charge=-2
#     MetaNetX: MNXM1628, formula=C8H6O6, charge=-2
#   5cmhm_c: C8H8O7, charge=0
#     MetaNetX: MNXM1163, formula=C8H8O7, charge=0
#
# Reaction CYANST compounds (excluding common cofactors):
#   cyan_c: CN, charge=-1
#     MetaNetX: MNXM254, formula=CN, charge=-1
#   tsul_c: HO3S2, charge=-1
#     MetaNetX: MNXM323, formula=HO3S2, charge=-1
#   so3_c: O3S, charge=-2
#     MetaNetX: MNXM105630, formula=O3S, charge=-2
#   tcynt_c: CNS, charge=-1
#     MetaNetX: MNXM762, formula=CNS, charge=-1
#
# Reaction CYO1ab compounds (excluding common cofactors):
#   ficytc_c: C42H52FeN8O6S2, charge=1
#     MetaNetX: MNXM5749, formula=C42H52FeN8O6S2, charge=0
#     DIFFERENCE: Model formula/charge = C42H52FeN8O6S2/1, MetaNetX = C42H52FeN8O6S2/0
#   q8h2_c: C49H76O4, charge=0
#     MetaNetX: MNXM202, formula=C14H20O4, charge=0
#     DIFFERENCE: Model formula/charge = C49H76O4/0, MetaNetX = C14H20O4/0
#   focytc_c: C42H52FeN8O6S2, charge=0
#     MetaNetX: MNXM746, formula=C42H52FeN8O6S2, charge=0
#   q8_c: C49H74O4, charge=0
#     MetaNetX: MNXM232, formula=C49H74O4, charge=0
#
# Reaction CYO2b compounds (excluding common cofactors):
#   focytc_c: C42H52FeN8O6S2, charge=0
#     MetaNetX: MNXM746, formula=C42H52FeN8O6S2, charge=0
#   ficytc_c: C42H52FeN8O6S2, charge=1
#     MetaNetX: MNXM5749, formula=C42H52FeN8O6S2, charge=0
#     DIFFERENCE: Model formula/charge = C42H52FeN8O6S2/1, MetaNetX = C42H52FeN8O6S2/0
#
# Reaction CYSBLY compounds (excluding common cofactors):
#   cyst__L_c: C7H14N2O4S, charge=0
#     MetaNetX: MNXM319, formula=C7H14N2O4S, charge=0
#   2amac_c: C3H5NO2, charge=0
#     MetaNetX: MNXM3414, formula=C3H5NO2, charge=0
#   hcys__L_c: C4H9NO2S, charge=0
#     MetaNetX: MNXM114070, formula=C4H9NO2S, charge=0
#
# Reaction DABAACT compounds (excluding common cofactors):
#   24dab_c: C4H11N2O2, charge=1
#     MetaNetX: MNXM840, formula=C4H11N2O2, charge=1
#   nac24dab_c: C6H12N2O3, charge=0
#     MetaNetX: MNXM2023, formula=C6H12N2O3, charge=0
#     BIGG API error for nac24dab: status 404
#
# Reaction DABAAT compounds (excluding common cofactors):
#   24dab_c: C4H11N2O2, charge=1
#     MetaNetX: MNXM840, formula=C4H11N2O2, charge=1
#   akg_c: C5H4O5, charge=-2
#     MetaNetX: MNXM20, formula=C5H4O5, charge=-2
#   aspsa_c: C4H7NO3, charge=0
#     MetaNetX: MNXM361, formula=C4H7NO3, charge=0
#
# Reaction DDALLO compounds (excluding common cofactors):
#   dtdp26ddgh2e2u_c: C16H20N2O14P2, charge=-2
#     MetaNetX: MNXM6260, formula=C16H20N2O14P2, charge=-2
#     BIGG API error for dtdp26ddgh2e2u: status 404
#   dtdp4dh26dall_c: C16H24N2O14P2, charge=0
#     MetaNetX: MNXM11453, formula=C16H24N2O14P2, charge=0
#     BIGG API error for dtdp4dh26dall: status 404
#
# Reaction DPCOX compounds (excluding common cofactors):
#   at44dcop_c: C30H40, charge=0
#     MetaNetX: MNXM1810, formula=C30H40, charge=0
#     BIGG API error for at44dcop: status 404
#   44dpcop_c: C30H36O2, charge=0
#     MetaNetX: MNXM4352, formula=C30H36O2, charge=0
#     BIGG API error for 44dpcop: status 404
#
# Reaction FMNAT compounds (excluding common cofactors):
#   fmn_c: C17H21N4O9P, charge=0
#     MetaNetX: MNXM119, formula=C17H21N4O9P, charge=0
#   fad_c: C27H31N9O15P2, charge=-2
#     MetaNetX: MNXM33, formula=C27H33N9O15P2, charge=0
#     DIFFERENCE: Model formula/charge = C27H31N9O15P2/-2, MetaNetX = C27H33N9O15P2/0
#
#   Updating fad_c to metanetx formula/charge would balance reaction FMNAT!
#     Did not update fad_c.
#
# Reaction FMNRx compounds (excluding common cofactors):
#   fmn_c: C17H21N4O9P, charge=0
#     MetaNetX: MNXM119, formula=C17H21N4O9P, charge=0
#   fmnh2_c: C17H21N4O9P, charge=-2
#     MetaNetX: MNXM208, formula=C17H20N4O9P, charge=-3
#     DIFFERENCE: Model formula/charge = C17H21N4O9P/-2, MetaNetX = C17H20N4O9P/-3
#
# Reaction FMNRx2 compounds (excluding common cofactors):
#   fmn_c: C17H21N4O9P, charge=0
#     MetaNetX: MNXM119, formula=C17H21N4O9P, charge=0
#   nadph_c: C21H26N7O17P3, charge=-4
#     MetaNetX: MNXM6, formula=C21H26N7O17P3, charge=-4
#   fmnh2_c: C17H21N4O9P, charge=-2
#     MetaNetX: MNXM208, formula=C17H20N4O9P, charge=-3
#     DIFFERENCE: Model formula/charge = C17H21N4O9P/-2, MetaNetX = C17H20N4O9P/-3
#   nadp_c: C21H25N7O17P3, charge=-3
#     MetaNetX: MNXM5, formula=C21H25N7O17P3, charge=-3
#
# Reaction G6PBDH compounds (excluding common cofactors):
#   g6p_B_c: C6H13O9P, charge=0
#     MetaNetX: MNXM508, formula=C6H13O9P, charge=0
#   nadp_c: C21H25N7O17P3, charge=-3
#     MetaNetX: MNXM5, formula=C21H25N7O17P3, charge=-3
#   6pgl_c: C6H9O9P, charge=-2
#     MetaNetX: MNXM429, formula=C6H9O9P, charge=-2
#   nadph_c: C21H26N7O17P3, charge=-4
#     MetaNetX: MNXM6, formula=C21H26N7O17P3, charge=-4
#
# Reaction G6PDH1b compounds (excluding common cofactors):
#   g6p_B_c: C6H13O9P, charge=0
#     MetaNetX: MNXM508, formula=C6H13O9P, charge=0
#   6pgl_c: C6H9O9P, charge=-2
#     MetaNetX: MNXM429, formula=C6H9O9P, charge=-2
#
# Reaction G6PI compounds (excluding common cofactors):
#   g6p_A_c: C6H11O9P, charge=-2
#     MetaNetX: MNXM215, formula=C6H11O9P, charge=-2
#   g6p_B_c: C6H13O9P, charge=0
#     MetaNetX: MNXM508, formula=C6H13O9P, charge=0
#
# Reaction GLUKB compounds (excluding common cofactors):
#   glc__bD_c: C6H12O6, charge=0
#     MetaNetX: MNXM722744, formula=C14H26O11, charge=0
#     DIFFERENCE: Model formula/charge = C6H12O6/0, MetaNetX = C14H26O11/0
#   g6p_B_c: C6H13O9P, charge=0
#     MetaNetX: MNXM508, formula=C6H13O9P, charge=0
#
# Reaction GUL5DH compounds (excluding common cofactors):
#   guln__L_c: C6H11O7, charge=-1
#     MetaNetX: MNXM1927, formula=C6H11O7, charge=-1
#   fruur_c: C6H10O7, charge=0
#     MetaNetX: MNXM1660, formula=C6H10O7, charge=0
#
# Reaction HCSUCT compounds (excluding common cofactors):
#   hdoxcad_c: C5H14N2O, charge=0
#     MetaNetX: MNXM8919, formula=C5H14N2O, charge=0
#     BIGG API error for hdoxcad: status 404
#   succoa_c: C25H35N7O19P3S, charge=-5
#     MetaNetX: MNXM92, formula=C25H35N7O19P3S, charge=-5
#   hyxsuccad_c: C9H18N2O4, charge=0
#     MetaNetX: MNXM6341, formula=C9H18N2O4, charge=0
#     BIGG API error for hyxsuccad: status 404
#
# Reaction HPHL compounds (excluding common cofactors):
#   prpncoa_c: C24H38N7O17P3S, charge=0
#     MetaNetX: MNXM78210, formula= , charge=None
#     DIFFERENCE: Model formula/charge = C24H38N7O17P3S/0, MetaNetX =  /None
#   3hpcoa_c: C24H36N7O18P3S, charge=-4
#     MetaNetX: MNXM1263, formula=C24H36N7O18P3S, charge=-4
#
# Reaction IZPN compounds (excluding common cofactors):
#   4izp_c: C6H7N2O3, charge=-1
#     MetaNetX: MNXM90394, formula=C6H8N2O3, charge=0
#     DIFFERENCE: Model formula/charge = C6H7N2O3/-1, MetaNetX = C6H8N2O3/0
#   forglu_c: C6H9N2O4, charge=-1
#     MetaNetX: MNXM496, formula=C6H9N2O4, charge=-1
#
#   Updating 4izp_c to metanetx formula/charge would balance reaction IZPN!
#     Updated 4izp_c in the model.
#
# Reaction MPML compounds (excluding common cofactors):
#   mg2_c: Mg, charge=2
#     MetaNetX: MNXM653, formula=Mg, charge=2
#   ppp9_c: C34H32N4O4, charge=-2
#     MetaNetX: MNXM346, formula=C34H32N4O4, charge=-2
#   mppp9_c: C34H32MgN4O4, charge=0
#     MetaNetX: MNXM2254, formula=C34H32MgN4O4, charge=0
#
# Reaction NADPHQR4 compounds (excluding common cofactors):
#   2dmmq9_c: C55H77O2, charge=-1
#     MetaNetX: MNXM7001, formula=C15H14O2, charge=0
#     DIFFERENCE: Model formula/charge = C55H77O2/-1, MetaNetX = C15H14O2/0
#     BIGG API error for 2dmmq9: status 404
#   nadph_c: C21H26N7O17P3, charge=-4
#     MetaNetX: MNXM6, formula=C21H26N7O17P3, charge=-4
#   2dmmql9_c: C55H80O2, charge=0
#     MetaNetX: MNXM17197, formula=C20H24O2, charge=0
#     DIFFERENCE: Model formula/charge = C55H80O2/0, MetaNetX = C20H24O2/0
#     BIGG API error for 2dmmql9: status 404
#   nadp_c: C21H25N7O17P3, charge=-3
#     MetaNetX: MNXM5, formula=C21H25N7O17P3, charge=-3
#
# Reaction NICMO compounds (excluding common cofactors):
#   nadph_c: C21H26N7O17P3, charge=-4
#     MetaNetX: MNXM6, formula=C21H26N7O17P3, charge=-4
#   nico__S_c: C10H14N2, charge=0
#     MetaNetX: MNXM90482, formula=C10H14N2, charge=0
#     BIGG API error for nico__S: status 404
#   nadp_c: C21H25N7O17P3, charge=-3
#     MetaNetX: MNXM5, formula=C21H25N7O17P3, charge=-3
#   nic1ox_c: C10H14N2O, charge=0
#     MetaNetX: MNXM12464, formula=C10H14N2O, charge=0
#     BIGG API error for nic1ox: status 404
#
# Reaction PCFO compounds (excluding common cofactors):
#   fadh2_c: C27H33N9O15P2, charge=-2
#     MetaNetX: MNXM38, formula= , charge=None
#     DIFFERENCE: Model formula/charge = C27H33N9O15P2/-2, MetaNetX =  /None
#   prpncoa_c: C24H38N7O17P3S, charge=0
#     MetaNetX: MNXM78210, formula= , charge=None
#     DIFFERENCE: Model formula/charge = C24H38N7O17P3S/0, MetaNetX =  /None
#   fad_c: C27H31N9O15P2, charge=-2
#     MetaNetX: MNXM33, formula=C27H33N9O15P2, charge=0
#     DIFFERENCE: Model formula/charge = C27H31N9O15P2/-2, MetaNetX = C27H33N9O15P2/0
#   ppcoa_c: C24H36N7O17P3S, charge=-4
#     MetaNetX: MNXM86, formula=C24H36N7O17P3S, charge=-4
#
# Reaction PHYFLUDS compounds (excluding common cofactors):
#   atphyflu_c: C40H62, charge=0
#     MetaNetX: MNXM2099, formula=C40H62, charge=0
#     BIGG API error for atphyflu: status 404
#   zcarote_c: C40H60, charge=0
#     MetaNetX: MNXM1039, formula=C40H60, charge=0
#
# Reaction PHYTDES compounds (excluding common cofactors):
#   15cphyt_c: C40H64, charge=0
#     MetaNetX: MNXM557, formula=C40H64, charge=0
#     BIGG API error for 15cphyt: status 404
#   atphyflu_c: C40H62, charge=0
#     MetaNetX: MNXM2099, formula=C40H62, charge=0
#     BIGG API error for atphyflu: status 404
#
# Reaction PPTRIAT compounds (excluding common cofactors):
#   pphinit_c: C5H12NO4P, charge=0
#     MetaNetX: MNXM59248, formula=C5H12NO4P, charge=0
#     BIGG API error for pphinit: status 404
#   nacpphin_c: C7H14NO5P, charge=0
#     MetaNetX: MNXM2844, formula=C7H12NO5P, charge=-2
#     DIFFERENCE: Model formula/charge = C7H14NO5P/0, MetaNetX = C7H12NO5P/-2
#     BIGG API error for nacpphin: status 404
#
# Reaction PSD181 compounds (excluding common cofactors):
#   ps181_c: C42H76NO10P, charge=-2
#     MetaNetX: MNXM221, formula=C8H11NO10P, charge=None
#     DIFFERENCE: Model formula/charge = C42H76NO10P/-2, MetaNetX = C8H11NO10P/None
#   pe181_c: C41H78N1O8P1, charge=0
#     MetaNetX: MNXM2150, formula=C41H78NO8P, charge=0
#     DIFFERENCE: Model formula/charge = C41H78N1O8P1/0, MetaNetX = C41H78NO8P/0
#
# Reaction PSSA181 compounds (excluding common cofactors):
#   cdpdodec11eg_c: C48H83N3O15P2, charge=-2
#     MetaNetX: MNXM201, formula=C14H17N3O15P2, charge=None
#     DIFFERENCE: Model formula/charge = C48H83N3O15P2/-2, MetaNetX = C14H17N3O15P2/None
#   ser__L_c: C3H7NO3, charge=0
#     MetaNetX: MNXM53, formula=C3H7NO3, charge=0
#   cmp_c: C9H12N3O8P, charge=-2
#     MetaNetX: MNXM31, formula=C9H12N3O8P, charge=-2
#   ps181_c: C42H76NO10P, charge=-2
#     MetaNetX: MNXM221, formula=C8H11NO10P, charge=None
#     DIFFERENCE: Model formula/charge = C42H76NO10P/-2, MetaNetX = C8H11NO10P/None
#
# Reaction RBFK compounds (excluding common cofactors):
#   ribflv_c: C17H20N4O6, charge=0
#     MetaNetX: MNXM270, formula=C17H19N4O6, charge=-1
#     DIFFERENCE: Model formula/charge = C17H20N4O6/0, MetaNetX = C17H19N4O6/-1
#   fmn_c: C17H21N4O9P, charge=0
#     MetaNetX: MNXM119, formula=C17H21N4O9P, charge=0
#
# Reaction S6PGB compounds (excluding common cofactors):
#   salcn6p_c: C13H17O10P, charge=-2
#     MetaNetX: MNXM3356, formula=C13H17O10P, charge=-2
#   2hymeph_c: C7H8O2, charge=0
#     MetaNetX: MNXM1855, formula=C7H8O2, charge=0
#   g6p_B_c: C6H13O9P, charge=0
#     MetaNetX: MNXM508, formula=C6H13O9P, charge=0
#
# Reaction SORBDH compounds (excluding common cofactors):
#   sorb14lac_c: C6H10O6, charge=0
#     MetaNetX: MNXM12065, formula=C6H10O6, charge=0
#     BIGG API error for sorb14lac: status 404
#   ascb__L_c: C6H7O6, charge=-1
#     MetaNetX: MNXM129, formula=C6H7O6, charge=-1
#
# Reaction SUCOAICT compounds (excluding common cofactors):
#   itacon_c: C5H6O4, charge=0
#     MetaNetX: MNXM1747, formula=C5H4O4, charge=-2
#     DIFFERENCE: Model formula/charge = C5H6O4/0, MetaNetX = C5H4O4/-2
#   succoa_c: C25H35N7O19P3S, charge=-5
#     MetaNetX: MNXM92, formula=C25H35N7O19P3S, charge=-5
#   itaccoa_c: C26H40N7O19P3S, charge=0
#     MetaNetX: MNXM1671, formula=C26H35N7O19P3S, charge=-5
#     DIFFERENCE: Model formula/charge = C26H40N7O19P3S/0, MetaNetX = C26H35N7O19P3S/-5
#
# Reaction TMDSf compounds (excluding common cofactors):
#   dump_c: C9H11N2O8P, charge=-2
#     MetaNetX: MNXM234, formula=C9H11N2O8P, charge=-2
#   fmnh2_c: C17H21N4O9P, charge=-2
#     MetaNetX: MNXM208, formula=C17H20N4O9P, charge=-3
#     DIFFERENCE: Model formula/charge = C17H21N4O9P/-2, MetaNetX = C17H20N4O9P/-3
#   mlthf_c: C20H21N7O6, charge=-2
#     MetaNetX: MNXM183, formula=C20H21N7O6, charge=-2
#   dtmp_c: C10H13N2O8P, charge=-2
#     MetaNetX: MNXM257, formula=C10H13N2O8P, charge=-2
#   fmn_c: C17H21N4O9P, charge=0
#     MetaNetX: MNXM119, formula=C17H21N4O9P, charge=0
#   thf_c: C19H21N7O6, charge=-2
#     MetaNetX: MNXM89609, formula= , charge=None
#     DIFFERENCE: Model formula/charge = C19H21N7O6/-2, MetaNetX =  /None
#
# Reaction ZCARDS compounds (excluding common cofactors):
#   zcarote_c: C40H60, charge=0
#     MetaNetX: MNXM1039, formula=C40H60, charge=0
#   neuspn_c: C40H58, charge=0
#     MetaNetX: MNXM949, formula=C40H58, charge=0
#
# Reaction ZCAROTDH2 compounds (excluding common cofactors):
#   neuspn_c: C40H58, charge=0
#     MetaNetX: MNXM949, formula=C40H58, charge=0
#   lycop_c: C40H56, charge=0
#     MetaNetX: MNXM445, formula=C40H56, charge=0
#
# Reaction CYO2a compounds (excluding common cofactors):
#   ficytc_c: C42H52FeN8O6S2, charge=1
#     MetaNetX: MNXM5749, formula=C42H52FeN8O6S2, charge=0
#     DIFFERENCE: Model formula/charge = C42H52FeN8O6S2/1, MetaNetX = C42H52FeN8O6S2/0
#   mql9_c: C56H82O2, charge=0
#     MetaNetX: MNXM442, formula=C16H18O2, charge=0
#     DIFFERENCE: Model formula/charge = C56H82O2/0, MetaNetX = C16H18O2/0
#     BIGG API error for mql9: status 404
#   focytc_c: C42H52FeN8O6S2, charge=0
#     MetaNetX: MNXM746, formula=C42H52FeN8O6S2, charge=0
#   h_e: H, charge=1
#     MetaNetX: MNXM1, formula=H, charge=1
#   mqn9_c: C56H80O2, charge=0
#     MetaNetX: MNXM166, formula=C16H16O2, charge=0
#     DIFFERENCE: Model formula/charge = C56H80O2/0, MetaNetX = C16H16O2/0
#
# Reaction NADH8 compounds (excluding common cofactors):
#   2dmmq9_c: C55H77O2, charge=-1
#     MetaNetX: MNXM7001, formula=C15H14O2, charge=0
#     DIFFERENCE: Model formula/charge = C55H77O2/-1, MetaNetX = C15H14O2/0
#     BIGG API error for 2dmmq9: status 404
#   2dmmql9_c: C55H80O2, charge=0
#     MetaNetX: MNXM17197, formula=C20H24O2, charge=0
#     DIFFERENCE: Model formula/charge = C55H80O2/0, MetaNetX = C20H24O2/0
#     BIGG API error for 2dmmql9: status 404
#   h_e: H, charge=1
#     MetaNetX: MNXM1, formula=H, charge=1
#
# Reaction FRD3 compounds (excluding common cofactors):
#   2dmmql9_c: C55H80O2, charge=0
#     MetaNetX: MNXM17197, formula=C20H24O2, charge=0
#     DIFFERENCE: Model formula/charge = C55H80O2/0, MetaNetX = C20H24O2/0
#     BIGG API error for 2dmmql9: status 404
#   fum_c: C4H2O4, charge=-2
#     MetaNetX: MNXM93, formula=C4H4O4, charge=0
#     DIFFERENCE: Model formula/charge = C4H2O4/-2, MetaNetX = C4H4O4/0
#   2dmmq9_c: C55H77O2, charge=-1
#     MetaNetX: MNXM7001, formula=C15H14O2, charge=0
#     DIFFERENCE: Model formula/charge = C55H77O2/-1, MetaNetX = C15H14O2/0
#     BIGG API error for 2dmmq9: status 404
#
# Reaction TRE6PPP compounds (excluding common cofactors):
#   tre6p_c: C12H21O14P, charge=-2
#     MetaNetX: MNXM448, formula=C12H21O14P, charge=-2
#   g6p_B_c: C6H13O9P, charge=0
#     MetaNetX: MNXM508, formula=C6H13O9P, charge=0
#   g1p_B_c: C6H11O9P, charge=-2
#     MetaNetX: MNXM679, formula=C6H11O9P, charge=-2
#
# Reaction PDE1 compounds (excluding common cofactors):
#   camp_c: C10H11N5O6P, charge=-1
#     MetaNetX: MNXM243, formula=C10H11N5O6P, charge=-1
#   amp_c: C10H12N5O7P, charge=-2
#     MetaNetX: MNXM14, formula=C10H12N5O7P, charge=-2
#
# Reaction PDH compounds (excluding common cofactors):
#
# Reaction OPAH compounds (excluding common cofactors):
#   5oxpro_c: C5H7NO3, charge=0
#     No MetaNetX ID found in annotation.
#
# Reaction ASP4DC compounds (excluding common cofactors):
#   asp__L_c: C4H6NO4, charge=-1
#     MetaNetX: MNXM42, formula=C4H7NO4, charge=0
#     DIFFERENCE: Model formula/charge = C4H6NO4/-1, MetaNetX = C4H7NO4/0
#   ala__L_c: C3H7NO2, charge=0
#     MetaNetX: MNXM32, formula=C3H7NO2, charge=0
#
#   Updating asp__L_c to metanetx formula/charge would balance reaction ASP4DC!
#     Did not update asp__L_c.
#
# Reaction PTRCAT1 compounds (excluding common cofactors):
#   ptrc_c: C4H14N2, charge=2
#     MetaNetX: MNXM118, formula=C4H14N2, charge=2
#   aprut_c: C6H14N2O, charge=0
#     No MetaNetX ID found in annotation.
#
# Reaction P5CRx compounds (excluding common cofactors):
#   1pyr5c_c: C5H6NO2, charge=-1
#     MetaNetX: MNXM1617, formula=C5H6NO2, charge=-1
#   pro__L_c: C5H9NO2, charge=0
#     MetaNetX: MNXM114, formula=C5H9NO2, charge=0
#
# Reaction DHBD compounds (excluding common cofactors):
#   23ddhb_c: C7H8O4, charge=0
#     No MetaNetX ID found in annotation.
#   23dhb_c: C7H5O4, charge=-1
#     No MetaNetX ID found in annotation.
#
# Reaction RBK_Dr compounds (excluding common cofactors):
#   rbl__D_c: C5H10O5, charge=0
#     No MetaNetX ID found in annotation.
#   ru5p__D_c: C5H9O8P, charge=-2
#     MetaNetX: MNXM145, formula=C5H9O8P, charge=-2
#
# Reaction GUAD compounds (excluding common cofactors):
#   gua_c: C5H5N5O, charge=0
#     MetaNetX: MNXM259, formula=C5H5N5O, charge=0
#   xan_c: C5H4N4O2, charge=0
#     MetaNetX: MNXM174, formula=C5H4N4O2, charge=0
#
# Reaction GLUKA compounds (excluding common cofactors):
#   Glc_aD_c: C6H12O6, charge=0
#     No MetaNetX ID found in annotation.
#   g6p_A_c: C6H11O9P, charge=-2
#     MetaNetX: MNXM215, formula=C6H11O9P, charge=-2
#
# Reaction AHAL compounds (excluding common cofactors):
#   achms_c: C6H11NO4, charge=0
#     MetaNetX: MNXM699, formula=C6H11NO4, charge=0
#   trdrd_c: XH2, charge=0
#     MetaNetX: MNXM96993, formula=C6H9NO2S2, charge=None
#     DIFFERENCE: Model formula/charge = XH2/0, MetaNetX = C6H9NO2S2/None
#   tsul_c: HO3S2, charge=-1
#     MetaNetX: MNXM323, formula=HO3S2, charge=-1
#   ac_c: C2H3O2, charge=-1
#     MetaNetX: MNXM26, formula=C2H3O2, charge=-1
#   hcys__L_c: C4H9NO2S, charge=0
#     MetaNetX: MNXM114070, formula=C4H9NO2S, charge=0
#   so3_c: O3S, charge=-2
#     MetaNetX: MNXM105630, formula=O3S, charge=-2
#   trdox_c: X, charge=0
#     MetaNetX: MNXM148, formula=C6H7NO2S2, charge=None
#     DIFFERENCE: Model formula/charge = X/0, MetaNetX = C6H7NO2S2/None
#
# Reaction TRYPTAOX compounds (excluding common cofactors):
#   trypta_c: C10H12N2, charge=0
#     No MetaNetX ID found in annotation.
#   id3acald_c: C10H9NO, charge=0
#     No MetaNetX ID found in annotation.
#
# Reaction APENTAMAH compounds (excluding common cofactors):
#   5apentam_c: C5H12N2O, charge=0
#     No MetaNetX ID found in annotation.
#   5aptn_c: C5H11NO2, charge=0
#     No MetaNetX ID found in annotation.
#
# Reaction G1PTT compounds (excluding common cofactors):
#   dttp_c: C10H13N2O14P3, charge=-4
#     MetaNetX: MNXM394, formula=C10H13N2O14P3, charge=-4
#   g1p_c: C6H11O9P, charge=-2
#     MetaNetX: MNXM89588, formula=C6H11O9P, charge=-2
#   dtdpglu_c: C16H24N2O16P2, charge=-2
#     MetaNetX: MNXM1376, formula=C16H24N2O16P2, charge=-2
#
# Reaction TYROXDAc compounds (excluding common cofactors):
#   tym_c: C8H11NO, charge=0
#     No MetaNetX ID found in annotation.
#   4hoxpacd_c: C8H8O2, charge=0
#     No MetaNetX ID found in annotation.
#
# Reaction RBK_L1 compounds (excluding common cofactors):
#   rbl__L_c: C5H10O5, charge=0
#     No MetaNetX ID found in annotation.
#   ru5p__L_c: C5H11O8P, charge=0
#     No MetaNetX ID found in annotation.
#
# Reaction AACTOOR compounds (excluding common cofactors):
#   aact_c: C3H7NO, charge=0
#     No MetaNetX ID found in annotation.
#   mthgxl_c: C3H4O2, charge=0
#     MetaNetX: MNXM310, formula=C3H4O2, charge=0
#
# Reaction 41R2A1H12BOOX compounds (excluding common cofactors):
#   nrpphr_c: C8H11NO3, charge=0
#     No MetaNetX ID found in annotation.
#   34dhmald_c: C8H8O4, charge=0
#     No MetaNetX ID found in annotation.
#
# Reaction PEAMNO compounds (excluding common cofactors):
#   peamn_c: C8H11N, charge=0
#     No MetaNetX ID found in annotation.
#   pacald_c: C8H8O, charge=0
#     MetaNetX: MNXM473, formula=C8H8O, charge=0
#
# Reaction 5HOXINOXDA compounds (excluding common cofactors):
#   srtn_c: C10H12N2O, charge=0
#     No MetaNetX ID found in annotation.
#   5hoxindact_c: C10H9NO2, charge=0
#     No MetaNetX ID found in annotation.
#
# Reaction HPROa compounds (excluding common cofactors):
#   1p3h5c_c: C5H6NO3, charge=-1
#     MetaNetX: MNXM114091, formula=C5H6NO3, charge=-1
#   4hpro_LT_c: C5H9NO3, charge=0
#     MetaNetX: MNXM87584, formula=C5H9NO3, charge=0
#
# Reaction NTRLASE2 compounds (excluding common cofactors):
#   aprop_c: C3H6N2, charge=0
#     No MetaNetX ID found in annotation.
#   ala__L_c: C3H7NO2, charge=0
#     MetaNetX: MNXM32, formula=C3H7NO2, charge=0
#
# Reaction FFSD compounds (excluding common cofactors):
#   suc6p_c: C12H23O14P, charge=0
#     No MetaNetX ID found in annotation.
#   fru_c: C6H12O6, charge=0
#     MetaNetX: MNXM1380, formula=C6H12O6, charge=0
#   g6p_c: C6H11O9P, charge=-2
#     MetaNetX: MNXM160, formula=C6H11O9P, charge=-2
#
# Reaction APRTO2 compounds (excluding common cofactors):
#   aprut_c: C6H14N2O, charge=0
#     No MetaNetX ID found in annotation.
#   n4abutn_c: C6H11NO2, charge=0
#     MetaNetX: MNXM1527, formula=C6H11NO2, charge=0
#
# Reaction ECH_3hivcoa compounds (excluding common cofactors):
#   3hivcoa_c: C26H44N7O18P3S, charge=0
#     No MetaNetX ID found in annotation.
#   3mb2coa_c: C26H38N7O17P3S, charge=-4
#     MetaNetX: MNXM389, formula=C26H38N7O17P3S, charge=-4
#
# Reaction 42A12BOOX compounds (excluding common cofactors):
#   dopa_c: C8H11NO2, charge=0
#     No MetaNetX ID found in annotation.
#   34dhpac_c: C8H8O3, charge=0
#     No MetaNetX ID found in annotation.
#
# Reaction MCITD compounds (excluding common cofactors):
#   2mcit_c: C7H10O7, charge=0
#     No MetaNetX ID found in annotation.
#   2mcacn_c: C7H5O6, charge=-3
#     No MetaNetX ID found in annotation.
#
# Reaction ACAS_2ahbut compounds (excluding common cofactors):
#   2obut_c: C4H5O3, charge=-1
#     MetaNetX: MNXM159, formula=C4H5O3, charge=-1
#   2ahethmpp_c: C14H23N4O8P2S+, charge=1
#     No MetaNetX ID found in annotation.
#   2ahbut_c: C6H9O4, charge=-1
#     MetaNetX: MNXM114220, formula=C6H9O4, charge=-1
#   thmpp_c: C12H16N4O7P2S, charge=-2
#     MetaNetX: MNXM256, formula=C12H16N4O7P2S, charge=-2
#
# Reaction AHSERL4 compounds (excluding common cofactors):
#   acser_c: C5H9NO4, charge=0
#     MetaNetX: MNXM418, formula=C5H9NO4, charge=0
#   trdrd_c: XH2, charge=0
#     MetaNetX: MNXM96993, formula=C6H9NO2S2, charge=None
#     DIFFERENCE: Model formula/charge = XH2/0, MetaNetX = C6H9NO2S2/None
#   tsul_c: HO3S2, charge=-1
#     MetaNetX: MNXM323, formula=HO3S2, charge=-1
#   ac_c: C2H3O2, charge=-1
#     MetaNetX: MNXM26, formula=C2H3O2, charge=-1
#   cys__L_c: C3H7NO2S, charge=0
#     MetaNetX: MNXM55, formula=C3H7NO2S, charge=0
#   so3_c: O3S, charge=-2
#     MetaNetX: MNXM105630, formula=O3S, charge=-2
#   trdox_c: X, charge=0
#     MetaNetX: MNXM148, formula=C6H7NO2S2, charge=None
#     DIFFERENCE: Model formula/charge = X/0, MetaNetX = C6H7NO2S2/None
#
# Reaction 3MOXTYROX compounds (excluding common cofactors):
#   3moxtyr_c: C9H13NO2, charge=0
#     No MetaNetX ID found in annotation.
#   3mox4hpac_c: C9H10O3, charge=0
#     No MetaNetX ID found in annotation.
#
# Reaction 3HXKYNOXDA compounds (excluding common cofactors):
#   3hxkynam_c: C9H12N2O2, charge=0
#     No MetaNetX ID found in annotation.
#   48dhoxquin_c: C9H7NO2, charge=0
#     No MetaNetX ID found in annotation.
#
# Reaction GLNSP2 compounds (excluding common cofactors):
#   uaaGgla_c: C94H156N8O26P2, charge=0
#     No MetaNetX ID found in annotation.
#   uaaGgtla_c: C94H157N9O25P2, charge=0
#     No MetaNetX ID found in annotation.
#
# Reaction GMHEPAT compounds (excluding common cofactors):
#   gmhep1p_c: C7H13O10P, charge=-2
#     No MetaNetX ID found in annotation.
#   adphep_DD_c: C17H27N5O16P2, charge=0
#     No MetaNetX ID found in annotation.
#
# Reaction RBP4E compounds (excluding common cofactors):
#   ru5p__L_c: C5H11O8P, charge=0
#     No MetaNetX ID found in annotation.
#   xu5p__D_c: C5H9O8P, charge=-2
#     MetaNetX: MNXM186, formula=C5H9O8P, charge=-2
#
# Reaction 6TXAN5MPAML compounds (excluding common cofactors):
#   gln__L_c: C5H10N2O3, charge=0
#     MetaNetX: MNXM37, formula=C5H10N2O3, charge=0
#   6txan5mp_c: C10H13N4O8PS, charge=0
#     No MetaNetX ID found in annotation.
#   amp_c: C10H12N5O7P, charge=-2
#     MetaNetX: MNXM14, formula=C10H12N5O7P, charge=-2
#   6tgsnmp_c: C10H14N5O7PS, charge=0
#     No MetaNetX ID found in annotation.
#
# Reaction DDMCITALOR compounds (excluding common cofactors):
#   ddmcital_c: C18H17FN2O, charge=0
#     No MetaNetX ID found in annotation.
#   citalald_c: C18H14FNO2, charge=0
#     No MetaNetX ID found in annotation.
#
# Reaction LPPGS compounds (excluding common cofactors):
#   gtp_c: C10H12N5O14P3, charge=-4
#     MetaNetX: MNXM51, formula=C10H12N5O14P3, charge=-4
#   2plac__L_c: C3H4O6P, charge=-3
#     No MetaNetX ID found in annotation.
#   lppg_c: C13H17N5O13P2, charge=-2
#     MetaNetX: MNXM2126, formula=C13H16N5O13P2, charge=-3
#     DIFFERENCE: Model formula/charge = C13H17N5O13P2/-2, MetaNetX = C13H16N5O13P2/-3
#
# Reaction KAS15 compounds (excluding common cofactors):
#   malACP_c: C14H22N2O10PRS, charge=-2
#     MetaNetX: MNXM184, formula=C3H3O3S, charge=None
#     DIFFERENCE: Model formula/charge = C14H22N2O10PRS/-2, MetaNetX = C3H3O3S/None
#   actACP_c: C15H25N2O9PRS, charge=-1
#     MetaNetX: MNXM1223, formula=C4H5O2S, charge=None
#     DIFFERENCE: Model formula/charge = C15H25N2O9PRS/-1, MetaNetX = C4H5O2S/None
#
# Reaction CBMD compounds (excluding common cofactors):
#   cbm_c: CH2NO2, charge=-1
#     No MetaNetX ID found in annotation.
#
# Reaction RE0691C compounds (excluding common cofactors):
#   4abutn_c: C4H10NO, charge=1
#     MetaNetX: MNXM422, formula=C4H10NO, charge=1
#   CE1944_c: C4H7N, charge=0
#     No MetaNetX ID found in annotation.
#
# Reaction SELGTHR compounds (excluding common cofactors):
#   gthrd_c: C10H16N3O6S, charge=-1
#     MetaNetX: MNXM57, formula=C10H16N3O6S, charge=-1
#   slnt_c: O3Se, charge=-2
#     No MetaNetX ID found in annotation.
#   gthox_c: C20H30N6O12S2, charge=-2
#     MetaNetX: MNXM151, formula=C20H30N6O12S2, charge=-2
#   dgslnt_c: C20H32N6O12S2Se, charge=0
#     No MetaNetX ID found in annotation.
#
# Reaction MCITS compounds (excluding common cofactors):
#   2mcit_c: C7H10O7, charge=0
#     No MetaNetX ID found in annotation.
#   oaa_c: C4H2O5, charge=-2
#     MetaNetX: MNXM46, formula=C4H2O5, charge=-2
#   ppcoa_c: C24H36N7O17P3S, charge=-4
#     MetaNetX: MNXM86, formula=C24H36N7O17P3S, charge=-4
#
# Reaction GALO compounds (excluding common cofactors):
#   gal_c: C6H12O6, charge=0
#     MetaNetX: MNXM390, formula=C6H12O6, charge=0
#   galctn__D_c: C6H11O7, charge=-1
#     No MetaNetX ID found in annotation.
#
# Reaction NBAH compounds (excluding common cofactors):
#   bgly_c: C9H9NO3, charge=0
#     No MetaNetX ID found in annotation.
#   bz_c: C7H5O2, charge=-1
#     MetaNetX: MNXM217, formula=C7H5O2, charge=-1
#   gly_c: C2H5NO2, charge=0
#     MetaNetX: MNXM29, formula=C2H5NO2, charge=0
#
# Reaction HKNDDH compounds (excluding common cofactors):
#   op4en_c: C5H5O3, charge=-1
#     No MetaNetX ID found in annotation.
#   hkndd_c: C9H10O6, charge=0
#     No MetaNetX ID found in annotation.
#
# Reaction PGMT_B compounds (excluding common cofactors):
#   g1p_B_c: C6H11O9P, charge=-2
#     MetaNetX: MNXM679, formula=C6H11O9P, charge=-2
#   g6p_B_c: C6H13O9P, charge=0
#     MetaNetX: MNXM508, formula=C6H13O9P, charge=0
#
# Reaction ICHORT compounds (excluding common cofactors):
#   ichor_c: C10H8O6, charge=-2
#     MetaNetX: MNXM799, formula=C10H8O6, charge=-2
#   23ddhb_c: C7H8O4, charge=0
#     No MetaNetX ID found in annotation.
#
# Reaction 3HPCOAHYD compounds (excluding common cofactors):
#   3hpp_c: C3H5O3, charge=-1
#     No MetaNetX ID found in annotation.
#   3hpcoa_c: C24H36N7O18P3S, charge=-4
#     MetaNetX: MNXM1263, formula=C24H36N7O18P3S, charge=-4
#
# Reaction HIBH compounds (excluding common cofactors):
#   3hibutcoa_c: C25H38N7O18P3S, charge=-4
#     MetaNetX: MNXM90341, formula=C25H38N7O18P3S, charge=-4
#   3hib_c: C4H7O3, charge=-1
#     No MetaNetX ID found in annotation.
#
# Reaction HKNTDH compounds (excluding common cofactors):
#   hkntd_c: C9H8O6, charge=0
#     No MetaNetX ID found in annotation.
#   fum_c: C4H2O4, charge=-2
#     MetaNetX: MNXM93, formula=C4H4O4, charge=0
#     DIFFERENCE: Model formula/charge = C4H2O4/-2, MetaNetX = C4H4O4/0
#   op4en_c: C5H5O3, charge=-1
#     No MetaNetX ID found in annotation.
#
# Reaction r_0001 compounds (excluding common cofactors):
#   chor_c: C10H8O6, charge=-2
#     MetaNetX: MNXM337, formula=C10H8O6, charge=-2
#   gln__L_c: C5H10N2O3, charge=0
#     MetaNetX: MNXM37, formula=C5H10N2O3, charge=0
#   m_0001: C10H11NO5, charge=0
#     No MetaNetX ID found in annotation.
#     BIGG API error for m_0001: status 404
#
# Reaction r_0002 compounds (excluding common cofactors):
#   m_0001: C10H11NO5, charge=0
#     No MetaNetX ID found in annotation.
#     BIGG API error for m_0001: status 404
#   m_0002: C7H9NO3, charge=0
#     No MetaNetX ID found in annotation.
#     BIGG API error for m_0002: status 404
#
# Reaction r_0011 compounds (excluding common cofactors):
#   amet_c: C15H23N6O5S, charge=1
#     MetaNetX: MNXM16, formula=C15H23N6O5S, charge=1
#   m_0008: C16H24N2O14P2, charge=0
#     No MetaNetX ID found in annotation.
#     BIGG API error for m_0008: status 404
#   ahcys_c: C14H20N6O5S, charge=0
#     MetaNetX: MNXM19, formula=C14H20N6O5S, charge=0
#   m_0009: C17H26N2O14P2, charge=0
#     No MetaNetX ID found in annotation.
#     BIGG API error for m_0009: status 404
#
# Reaction metylmalonyl_synthesis compounds (excluding common cofactors):
#   ppcoa_c: C24H36N7O17P3S, charge=-4
#     MetaNetX: MNXM86, formula=C24H36N7O17P3S, charge=-4
#   hco3_c: CHO3, charge=-1
#     MetaNetX: MNXM60, formula=CHO3, charge=-1
#   mmcoa_c: C25H40N7O19P3S, charge=0
#     No MetaNetX ID found in annotation.
#     BIGG API error for mmcoa: status 404
#
# Reaction ethylmalonyl_synthesis compounds (excluding common cofactors):
#   nadph_c: C21H26N7O17P3, charge=-4
#     MetaNetX: MNXM6, formula=C21H26N7O17P3, charge=-4
#   b2coa_c: C25H36N7O17P3S, charge=-4
#     MetaNetX: MNXM214, formula=C25H36N7O17P3S, charge=-4
#   ethmalcoa_c: C26H42N7O19P3S, charge=0
#     No MetaNetX ID found in annotation.
#   nadp_c: C21H25N7O17P3, charge=-3
#     MetaNetX: MNXM5, formula=C21H25N7O17P3, charge=-3
#
# Reaction FBA4 compounds (excluding common cofactors):
#   xu1p__D_c: C5H11O8P, charge=0
#     MetaNetX: MNXM59594, formula=C5H11O8P, charge=0
#   dhap_c: C3H5O6P, charge=-2
#     MetaNetX: MNXM77, formula=C3H5O6P, charge=-2
#   gcald_c: C2H4O2, charge=0
#     MetaNetX: MNXM349, formula=C2H4O2, charge=0
#
# Reaction PHYCBOXL compounds (excluding common cofactors):
#   phe__L_c: C9H11NO2, charge=0
#     MetaNetX: MNXM97, formula=C9H11NO2, charge=0
#   peamn_c: C8H11N, charge=0
#     No MetaNetX ID found in annotation.
#
# Reaction KHK2 compounds (excluding common cofactors):
#   xylu__L_c: C5H10O5, charge=0
#     MetaNetX: MNXM1282, formula=C5H10O5, charge=0
#   xu1p__D_c: C5H11O8P, charge=0
#     MetaNetX: MNXM59594, formula=C5H11O8P, charge=0

# %% [markdown]
# # 3. Manual Correction of Imbalanced Reactions

# %%
# Iterate through each reaction in the model
for reaction in model.reactions.get_by_any('3OXCOADH'):
    try:
        imbalance = reaction.check_mass_balance()
    except:
        imbalance = None
    if imbalance:
        print(reaction, reaction.name)
        print(reaction.annotation)
        for m in reaction.reactants:
            print(m, m.formula, m.charge)
        for m in reaction.products:
            print(m, m.formula, m.charge)
# Out:
# 3OXCOADH: 3oc4en24ocoa_c + acceptor_c --> 3ocdncoa_c + donor_c 3-oxochol-4-en-24-oyl-CoA dehydrogenase
# {'sbo': 'SBO:0000176', 'ec-code': '1.3.99', 'bigg.reaction': '3OXCOADH', 'biocyc': 'RXN-12707', 'origin': 'Sco4', 'metanetx.reaction': 'MNXR140272', 'pathway': 'Steroid degradation', 'subsystem': 'Xenobiotics biodegradation and metabolism'}
# 3oc4en24ocoa_c C45H66N7O18P3S -4
# acceptor_c R 0
# 3ocdncoa_c C45H64N7O18P3S -4
# donor_c RH -1

# %%
# Iterate through each reaction in the model
model.metabolites.get_by_id('acceptor_c').formula = 'R'
model.metabolites.get_by_id('acceptor_c').charge = 0

# %% [markdown]
# # 4. Manually Add Extra Reactions

# %%
from cobra.core import Reaction

model.remove_reactions([model.reactions.DHPDH_1, model.reactions.DHPDH_2])

rxn13121 = Reaction("DHPDH_1", name="Dihydropyrimidine dehydrogenase", lower_bound=0, upper_bound=100)

rxn13121.annotation = {"ec-code": "1.3.1.2", 
                       "biocyc": "1.3.1.3-RXN", 
                       "metanetx.reaction": "MNXR97814", 
                       "seed.reaction":"rxn00719", 
                       "rhea": "18093", 
                       "subsystem": "uracil degradation"}


rxn13122 = Reaction("DHPDH_2", name="Dihydropyrimidine dehydrogenase", lower_bound=0, upper_bound=100)

rxn13122.annotation = {"ec-code": "1.3.1.2", 
                       "biocyc": "RXN-11209", 
                       "seed.reaction":"rxn01027", 
                       "rhea": "58284",
                       "subsystem": "thymine degradation"}

rxn26140 = Reaction("3HMPPYRAT", name="(R)-3-amino-2-methylpropionate—pyruvate transaminase", lower_bound=0, upper_bound=100)

rxn26140.annotation = {"ec-code": "2.6.1.40", 
                       "biocyc": "2.6.1.40-RXN",
                       "metanetx.reaction": "MNXR115181", 
                       "seed.reaction":"rxn15297", 
                       "rhea": "18396",
                       "subsystem": "thymine degradation"}

rxn25148 = Reaction("OSHSL", name="O-succinyl-L-homoserine succinate-lyase", lower_bound=0, upper_bound=100)
rxn25148.gene_reaction_rule = 'XNR_4037'
rxn25148.annotation = {"ec-code": "2.5.1.48",
                       "biocyc": "RXN-18602",
                       "kegg.reaction": "R00651", 
                       "seed.reaction":"rxn15297", 
                       "rhea": "18396",
                       "subsystem": "Cysteine and methionine metabolism"}

rxn25149 = Reaction("AHSERL", name="O-acetyl-L-homoserine acetate-lyase", lower_bound=0, upper_bound=100)
rxn25149.gene_reaction_rule = 'XNR_0869'
rxn25149.annotation = {"ec-code": "2.5.1.49",
                       "biocyc": "O-ACETYLHOMOSERINE-THIOL-LYASE-RXN",
                       "kegg.reaction": "R00651", 
                       "metanetx.reaction":"MNXR95634", 
                       "rhea": "10049",
                       "subsystem": "Cysteine and methionine metabolism"}

rxn2311 = Reaction("ARGJ", name="amino acid acetyltransferase", lower_bound=0, upper_bound=100)
rxn2311.gene_reaction_rule = 'XNR_5266'
rxn2311.annotation = {"ec-code": "2.3.1.1",
                       "biocyc": "RXN0-6948",
                       "kegg.reaction": "R00651", 
                       "seed.reaction":"rxn15297", 
                       "rhea": "18396",
                       "subsystem": "Cysteine and methionine metabolism"}

rxn44111 = Reaction("METGL", name="methionine gamma-lyase", lower_bound=0, upper_bound=100)
rxn44111.gene_reaction_rule = 'XNR_5540'
rxn44111.annotation = {"ec-code": "4.4.1.11",
                       "biocyc": "METHIONINE-GAMMA-LYASE-RXN",
                       "kegg.reaction": "R00654", 
                       "seed.reaction":"rxn00456", 
                       "metanetx.reaction":"MNXR101474", 
                       "rhea": "23801",
                       "subsystem": "Cysteine and methionine metabolism"}

acmet_c = cobra.Metabolite('acmet_c',formula='C7H12NO3S', name='N-acetyl-L-methionine', compartment='c', charge=-1)
acmet_c.annotation = {
    'pubchem.compound': '448580',
    'chebi': 'CHEBI:71670',
    'kegg.compound': 'C02712'
}
ch4s_c = cobra.Metabolite('ch4s_c',formula='CH4S', name='Methanethiol', compartment='c', charge=0)
ch4s_c.annotation = {
    'pubchem.compound': '878',
    'chebi': 'CHEBI:14586',
    'kegg.compound': 'C00409'
}

model.add_metabolites([acmet_c, ch4s_c])
model.add_reactions([rxn13121, rxn13122, rxn26140, rxn25148, rxn25149, rxn2311, rxn44111])
model.reactions.DHPDH_1.build_reaction_from_string("56dura_c + nadp_c <-- ura_c + nadph_c + h_c")
model.reactions.DHPDH_2.build_reaction_from_string("56dthm_c + nadp_c <-- thym_c + nadph_c + h_c")
model.reactions.get_by_id('3HMPPYRAT').build_reaction_from_string("3aib_c + pyr_c --> ala__L_c + 2mop_c")

model.reactions.OSHSL.build_reaction_from_string("suchms_c + ch4s_c --> met__L_c + succ_c + h_c")
model.reactions.AHSERL.build_reaction_from_string("achms_c + ch4s_c --> met__L_c + ac_c + h_c")
model.reactions.ARGJ.build_reaction_from_string("met__L_c + accoa_c --> acmet_c + coa_c + h_c")
model.reactions.METGL.build_reaction_from_string("met__L_c + h2o_c --> nh4_c + ch4s_c + 2obut_c")

# %%
from cobra.io import write_sbml_model, save_json_model

write_sbml_model(model, 'Salb-GEM-Biosustain.xml')
save_json_model(model, 'Salb-GEM-Biosustain.json')

# %%
# %%bash
#
# memote report snapshot ../4.mass_balance/Salb-GEM-Biosustain.xml
# Out:
# error: unrecognized subcommand 'memote'
#
# Usage: uv [OPTIONS] <COMMAND>
#
# For more information, try '--help'.
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[172], line 1
# ----> 1 get_ipython().run_cell_magic('bash', '', '\nuv memote report snapshot ../4.mass_balance/Salb-GEM-Biosustain.xml\n')
#
# File ~/biosustain/projects/strepto/streptsd/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2549, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2547 with self.builtin_trap:
#    2548     args = (magic_arg_s, cell)
# -> 2549     result = fn(*args, **kwargs)
#    2551 # The code below prevents the output from being displayed
#    2552 # when using magics with decorator @output_can_be_silenced
#    2553 # when the last Python token in the expression is a ';'.
#    2554 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/biosustain/projects/strepto/streptsd/.venv/lib/python3.12/site-packages/IPython/core/magics/script.py:159, in ScriptMagics._make_script_magic.<locals>.named_script_magic(line, cell)
#     157 else:
#     158     line = script
# --> 159 return self.shebang(line, cell)
#
# File ~/biosustain/projects/strepto/streptsd/.venv/lib/python3.12/site-packages/IPython/core/magics/script.py:336, in ScriptMagics.shebang(self, line, cell)
#     331 if args.raise_error and p.returncode != 0:
#     332     # If we get here and p.returncode is still None, we must have
#     333     # killed it but not yet seen its return code. We don't wait for it,
#     334     # in case it's stuck in uninterruptible sleep. -9 = SIGKILL
#     335     rc = p.returncode or -9
# --> 336     raise CalledProcessError(rc, cell)
#
# CalledProcessError: Command 'b'\nuv memote report snapshot ../4.mass_balance/Salb-GEM-Biosustain.xml\n'' returned non-zero exit status 2.
