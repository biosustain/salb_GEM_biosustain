# %% [markdown]
# # Gapfilling with Universal Model

# %%
import cobra
from cobra.core import Metabolite, Reaction
from cobra.io import read_sbml_model, load_json_model
from cobra.flux_analysis import gapfill
import os, re
import pandas as pd

print(os.getcwd())

ext_dir = '/../../../data/external'
phenomics = '/../../phenomics'
sco_dir = '/../1.gapfill_w_sco'

# Import model
# model = read_sbml_model(f"{os.getcwd()}/{ext_dir}/Salb-GEM.xml")
model = read_sbml_model(f"{os.getcwd()}/{sco_dir}/Salb-GEM-Sco-gapfill.xml")

# Mapping of the universal reaction model
universal = load_json_model(f"{os.getcwd()}/{ext_dir}/universal_model_cobrapy.json")
# Out:
# /Users/te/Library/CloudStorage/OneDrive-Personal/Biosustain/strep/Code/streptsd/notebooks/gapfilling/2.gapfill_w_universal
# '' is not a valid SBML 'SId'.
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-11-13

# %% [markdown]
# # 1. Get all untestable and false negative compounds

# %%
# Import agreed biolog vs model data
agreed_bio_data = pd.read_csv(f"{os.getcwd()}{sco_dir}/agreed_bio_data_Salb_Sco.csv")
agreed_bio_data['model_simulation_0.05'] = agreed_bio_data['model_simulation_0.05'].astype('boolean')

# # Mapping between bigg and metax names
# bigg_mnmx = pd.read_json(f"{os.getcwd()}/{ext_dir}/metanetx.json")

# # Mapping files for bigg compound to all other names
# name_map = pd.read_csv(f"{os.getcwd()}/{ext_dir}/biggmodels_metabolites.txt",sep='\t')
# name_map = name_map.drop(['bigg_id', 'model_list', 'old_bigg_ids'], axis=1)

agreed_bio_data
# Out:
#         index  activity                       chemical             category  \
# 0    PM01_A01     False               Negative Control               carbon
# 1    PM01_A02      True                    L-Arabinose               carbon
# 2    PM01_A03      True         N-Acetyl-D-Glucosamine               carbon
# 3    PM01_A04     False               D-Saccharic acid               carbon
# 4    PM01_A05      True                  Succinic acid               carbon
# ..        ...       ...                            ...                  ...
# 379  PM04_H08     False   p-Aminobenzene Sulfonic acid  phosphate & sulphur
# 380  PM04_H09     False           Butane Sulfonic acid  phosphate & sulphur
# 381  PM04_H10     False  2-Hydroxyethane Sulfonic acid  phosphate & sulphur
# 382  PM04_H11     False          Methane Sulfonic acid  phosphate & sulphur
# 383  PM04_H12     False         Tetramethylene Sulfone  phosphate & sulphur
#
#                             moa     bigg      exchange  model_simulation_0.05  \
# 0    C-Source, negative control        #             #                   <NA>
# 1        C-Source, carbohydrate  arab__L  EX_arab__L_e                   True
# 2        C-Source, carbohydrate    acgam    EX_acgam_e                   <NA>
# 3     C-Source, carboxylic acid     glcr     EX_glcr_e                   <NA>
# 4     C-Source, carboxylic acid     succ     EX_succ_e                   True
# ..                          ...      ...           ...                    ...
# 379           S-Source, organic     4abz     EX_4abz_e                   <NA>
# 380           S-Source, organic   butso3   EX_butso3_e                   <NA>
# 381           S-Source, organic   isetac   EX_isetac_e                   <NA>
# 382           S-Source, organic     mso3     EX_mso3_e                   <NA>
# 383           S-Source, organic        #             #                   <NA>
#
#     model_simulation_0.1 model_simulation_0.2
# 0                    NaN                  NaN
# 1                   True                 True
# 2                    NaN                  NaN
# 3                    NaN                  NaN
# 4                   True                 True
# ..                   ...                  ...
# 379                  NaN                  NaN
# 380                  NaN                  NaN
# 381                  NaN                  NaN
# 382                  NaN                  NaN
# 383                  NaN                  NaN
#
# [384 rows x 10 columns]

# %%
print(f"\nFalse negative (actual true, predicted false):\n")
agreed_bio_data_nan_drop = agreed_bio_data[agreed_bio_data['model_simulation_0.05'].notna()]
false_negatives = agreed_bio_data_nan_drop[
    agreed_bio_data_nan_drop.xs("activity", axis=1)
    & ~(agreed_bio_data_nan_drop.xs("model_simulation_0.05", axis=1))
    ][["bigg","chemical", "moa", "exchange", "model_simulation_0.05"]]

print(false_negatives)

false_negatives.to_csv(os.getcwd() + "/" + 'Salb_false_negative.csv', index=True)
# Out:
# False negative (actual true, predicted false):
#
#         bigg                 chemical                   moa      exchange  \
# 179   met__L             L-Methionine  C-Source, amino acid   EX_met__L_e
# 225  citr__L             L-Citrulline  N-Source, amino acid  EX_citr__L_e
# 226   hom__L             L-Homoserine  N-Source, amino acid   EX_hom__L_e
# 259     thym                  Thymine       N-Source, other     EX_thym_e
# 260    thymd                Thymidine       N-Source, other    EX_thymd_e
# 261      ura                   Uracil       N-Source, other      EX_ura_e
# 262      uri                  Uridine       N-Source, other      EX_uri_e
# 302   glyc3p  DL-a-Glycerol Phosphate     P-Source, organic   EX_glyc3p_e
#
#      model_simulation_0.05
# 179                  False
# 225                  False
# 226                  False
# 259                  False
# 260                  False
# 261                  False
# 262                  False
# 302                  False

# %% [markdown]
# # 2. Try Gapfilling Function on false negatives

# %%
def basic_gapfill(bigg, model, reference, objective='growth', iter=1):
    """
    gapfill a model using reference model and cplex solver.
    
    Parameters:
    -----------
    bigg: String
    model: Model
    reference: Model
    """
    print(f"\nGapfilling {bigg} with: ")
    with reference:
        reference.solver = 'cplex'
        model.solver = 'cplex'
        model.objective = objective
        solution = gapfill(model, reference, demand_reactions=False, iterations=iter)
        print(solution)
    return solution 

def gapfill_medium(model, reference, bigg, type, exchange):
    """
    This function does gapfilling based on a chemical in the certain biolog medium and add an exchange reaction if needed"
    
    Parameters:
    -----------
    bigg (str) 
    category (str)
    exchange (str)
    """

    # when model has the exchange reaction, no need to add a reaction before gapfilling.  
    try:
        with model:
            medium = model.medium
            medium[exchange] = 0.8
            if type.startswith("C"):
                medium["EX_glc__D_e"] = 0

            elif type.startswith("N"):
                medium["EX_nh4_e"] = 0

            elif type.startswith("P"):
                medium["EX_pi_e"] = 0
            
            elif type.startswith("S"):
                medium["EX_so4_e"] = 0

            model.medium = medium
            model.reactions.EX_co2_e.bounds= (0, 1000)

            return basic_gapfill(bigg, model, reference, 'growth', 4)
    except:
        print(f"Gapfilling of the compound {bigg} - {type} - {exchange} is failed\n")
        return None

# %%
_model = model.copy()
with open('gapfill_reactions.txt', 'w') as file:
    for ind in false_negatives.index:
        file.write(f"Gapfilling {false_negatives['bigg'][ind]}, {false_negatives['moa'][ind]} with:\n")
        solution = gapfill_medium(_model, universal, false_negatives['bigg'][ind], false_negatives['moa'][ind], false_negatives['exchange'][ind])
        if solution:
            unique_solution = set([reaction for reaction_set in solution for reaction in reaction_set])
            reactions_str = ', '.join(str(reaction.id) for reaction in unique_solution)
            print(reactions_str)
            file.write(reactions_str + '\n\n')
        else:
            file.write('\n\n')
# Out:
# Read LP format model from file /var/folders/wy/8d18n83n56j78d4j6zkz449m0000gn/T/tmpvizkxmtf.lp
# Reading time = 0.01 seconds
# : 1886 rows, 4524 columns, 19812 nonzeros
#
# Gapfilling met__L with:
# [[<Reaction SLGTH at 0x7fc29757bdf0>], [<Reaction GLYFEM at 0x7fc2a7037490>], [<Reaction SUCptspp_1 at 0x7fc2604925e0>], [<Reaction FACT at 0x7fc2819f2dc0>]]
# GLYFEM, FACT, SUCptspp_1, SLGTH
#
# Gapfilling citr__L with:
# [[<Reaction SLGTH at 0x7fc25055aac0>], [<Reaction OCBT2i at 0x7fc2215c9400>], [<Reaction SDPDS_2 at 0x7fc2484b00d0>], [<Reaction ARGDC at 0x7fc269a08400>]]
# OCBT2i, ARGDC, SLGTH, SDPDS_2
#
# Gapfilling hom__L with:
# [[<Reaction SLGTH at 0x7fc1e3f34370>], [<Reaction HOMt4 at 0x7fc1e05c00a0>], [<Reaction r1891 at 0x7fc2554da430>], [<Reaction HMR_9726 at 0x7fc2435713a0>]]
# HOMt4, r1891, HMR_9726, SLGTH
#
# Gapfilling thym with:
# [[<Reaction SLGTH at 0x7fc21b69cd60>], [<Reaction SDPDS_2 at 0x7fc203c00370>], [<Reaction NRRH at 0x7fc203c00490>], [<Reaction SRK at 0x7fc26db617c0>]]
# NRRH, SRK, SLGTH, SDPDS_2
#
# Gapfilling thymd with:
# [[<Reaction SLGTH at 0x7fc1ce360640>], [<Reaction SRK at 0x7fc1b17360a0>], [<Reaction NP1_2 at 0x7fc1a1b51ee0>], [<Reaction THDPS_2 at 0x7fc1a1b51e50>]]
# SRK, SLGTH, THDPS_2, NP1_2
#
# Gapfilling ura with:
# [[<Reaction NP1_2 at 0x7fc21dc769a0>], [<Reaction HMR_9726 at 0x7fc21f1c9130>], [<Reaction SLGTH at 0x7fc1b01d3100>], [<Reaction SRK at 0x7fc1b27f2b20>]]
# SLGTH, NP1_2, HMR_9726, SRK
#
# Gapfilling uri with:
# [[<Reaction SRK at 0x7fc1d0748460>], [<Reaction THDPS_2 at 0x7fc160113250>], [<Reaction HMR_9726 at 0x7fc1d68cba30>], [<Reaction SDPDS_2 at 0x7fc1d0847fd0>]]
# SDPDS_2, HMR_9726, THDPS_2, SRK
#
# Gapfilling glyc3p with:
# [[<Reaction GLYC3tr at 0x7fc17677f160>], [<Reaction DHPS2_2 at 0x7fc1d55b2550>], [<Reaction CPS_1 at 0x7fc1c7cb6f10>], [<Reaction GLY3Pt2 at 0x7fc16075dbb0>]]
# CPS_1, GLY3Pt2, DHPS2_2, GLYC3tr

# %%
# Initialize an empty list to store the extracted lists
gapfill_lists = []

# Open and read the file
with open('gapfill_reactions.txt', 'r') as file:
    lines = file.readlines()

# Process every second line and split it into a list
for i in range(1, len(lines), 3):
    reaction_list = [item.strip() for item in lines[i].strip().split(',')]
    gapfill_lists.extend(reaction_list)

merged_lists = set(gapfill_lists)
merged_lists.discard('')

# Print the extracted lists
print(merged_lists)
# Out:
# {'FACT', 'ARGDC', 'DHPS2_2', 'NRRH', 'CPS_1', 'SUCptspp_1', 'SRK', 'GLY3Pt2', 'SLGTH', 'NP1_2', 'SDPDS_2', 'r1891', 'THDPS_2', 'GLYC3tr', 'HOMt4', 'OCBT2i', 'GLYFEM', 'HMR_9726'}

# %% [markdown]
# # 3. Get a short list by testing new reactions
# Some reactions in Universal is not well documented and can result in bad model. Therefore, we test the model using database search

# %%
short_list = []
for reaction_id in merged_lists:
    # Get the reaction from the reference model
    reaction = universal.reactions.get_by_id(reaction_id)
    model_temp = model.copy()
    
    with model_temp:
        # Add a copy of the reaction to your model
        model_temp.add_reactions([reaction.copy()])
        model_temp.solver ='cplex'
        model_temp.reactions.EX_co2_e.bounds= (0, 1000)

        solution = model_temp.optimize()
        print (f"------\nTest with {reaction_id} \nSolution: {solution}\n--------")

        if solution.objective_value < 1:
            short_list.append(reaction_id)

short_list
# Out:
# Read LP format model from file /var/folders/wy/8d18n83n56j78d4j6zkz449m0000gn/T/tmp88c7cni8.lp
# Reading time = 0.02 seconds
# : 1886 rows, 4524 columns, 19812 nonzeros
# ------
# Test with FACT
# Solution: <Solution 3.380 at 0x7fc18fed96d0>
# --------
# Read LP format model from file /var/folders/wy/8d18n83n56j78d4j6zkz449m0000gn/T/tmp4232jmv3.lp
# Reading time = 0.01 seconds
# : 1886 rows, 4524 columns, 19812 nonzeros
# ------
# Test with ARGDC
# Solution: <Solution 0.156 at 0x7fc1703e3490>
# --------
# Read LP format model from file /var/folders/wy/8d18n83n56j78d4j6zkz449m0000gn/T/tmpron4fyja.lp
# Reading time = 0.01 seconds
# : 1886 rows, 4524 columns, 19812 nonzeros
# ------
# Test with DHPS2_2
# Solution: <Solution 0.156 at 0x7fc120ef83d0>
# --------
# Read LP format model from file /var/folders/wy/8d18n83n56j78d4j6zkz449m0000gn/T/tmp_c9y5w44.lp
# Reading time = 0.02 seconds
# : 1886 rows, 4524 columns, 19812 nonzeros
# ------
# Test with NRRH
# Solution: <Solution 0.156 at 0x7fc170943370>
# --------
# Read LP format model from file /var/folders/wy/8d18n83n56j78d4j6zkz449m0000gn/T/tmp75yvz29e.lp
# Reading time = 0.01 seconds
# : 1886 rows, 4524 columns, 19812 nonzeros
# ------
# Test with CPS_1
# Solution: <Solution 0.156 at 0x7fc17007b3a0>
# --------
# Read LP format model from file /var/folders/wy/8d18n83n56j78d4j6zkz449m0000gn/T/tmpz4wz1zb6.lp
# Reading time = 0.02 seconds
# : 1886 rows, 4524 columns, 19812 nonzeros
# ------
# Test with SUCptspp_1
# Solution: <Solution 20.452 at 0x7fc1af075190>
# --------
# Read LP format model from file /var/folders/wy/8d18n83n56j78d4j6zkz449m0000gn/T/tmpu_u2ages.lp
# Reading time = 0.03 seconds
# : 1886 rows, 4524 columns, 19812 nonzeros
# ------
# Test with SRK
# Solution: <Solution 0.163 at 0x7fc193b57100>
# --------
# Read LP format model from file /var/folders/wy/8d18n83n56j78d4j6zkz449m0000gn/T/tmpxcb624v_.lp
# Reading time = 0.02 seconds
# : 1886 rows, 4524 columns, 19812 nonzeros
# ------
# Test with GLY3Pt2
# Solution: <Solution 0.156 at 0x7fc1226007f0>
# --------
# Read LP format model from file /var/folders/wy/8d18n83n56j78d4j6zkz449m0000gn/T/tmp0y_8dael.lp
# Reading time = 0.03 seconds
# : 1886 rows, 4524 columns, 19812 nonzeros
# ------
# Test with SLGTH
# Solution: <Solution 11.732 at 0x7fc170973be0>
# --------
# Read LP format model from file /var/folders/wy/8d18n83n56j78d4j6zkz449m0000gn/T/tmpzmgwdqk1.lp
# Reading time = 0.02 seconds
# : 1886 rows, 4524 columns, 19812 nonzeros
# ------
# Test with NP1_2
# Solution: <Solution 0.156 at 0x7fc122892b50>
# --------
# Read LP format model from file /var/folders/wy/8d18n83n56j78d4j6zkz449m0000gn/T/tmplwhbbgbs.lp
# Reading time = 0.02 seconds
# : 1886 rows, 4524 columns, 19812 nonzeros
# ------
# Test with SDPDS_2
# Solution: <Solution 0.163 at 0x7fc196159a90>
# --------
# Read LP format model from file /var/folders/wy/8d18n83n56j78d4j6zkz449m0000gn/T/tmpq7sa15t0.lp
# Reading time = 0.02 seconds
# : 1886 rows, 4524 columns, 19812 nonzeros
# ------
# Test with r1891
# Solution: <Solution 0.156 at 0x7fc102ba6a60>
# --------
# Read LP format model from file /var/folders/wy/8d18n83n56j78d4j6zkz449m0000gn/T/tmpk5il56u5.lp
# Reading time = 0.01 seconds
# : 1886 rows, 4524 columns, 19812 nonzeros
# ------
# Test with THDPS_2
# Solution: <Solution 0.163 at 0x7fc197aaca00>
# --------
# Read LP format model from file /var/folders/wy/8d18n83n56j78d4j6zkz449m0000gn/T/tmpys_z8yhr.lp
# Reading time = 0.02 seconds
# : 1886 rows, 4524 columns, 19812 nonzeros
# ------
# Test with GLYC3tr
# Solution: <Solution 0.156 at 0x7fc17373a850>
# --------
# Read LP format model from file /var/folders/wy/8d18n83n56j78d4j6zkz449m0000gn/T/tmps4y94ag1.lp
# Reading time = 0.01 seconds
# : 1886 rows, 4524 columns, 19812 nonzeros
# ------
# Test with HOMt4
# Solution: <Solution 0.156 at 0x7fc10398b760>
# --------
# Read LP format model from file /var/folders/wy/8d18n83n56j78d4j6zkz449m0000gn/T/tmp4uufka3y.lp
# Reading time = 0.02 seconds
# : 1886 rows, 4524 columns, 19812 nonzeros
# ------
# Test with OCBT2i
# Solution: <Solution 0.156 at 0x7fc1102c96d0>
# --------
# Read LP format model from file /var/folders/wy/8d18n83n56j78d4j6zkz449m0000gn/T/tmp88faizdc.lp
# Reading time = 0.02 seconds
# : 1886 rows, 4524 columns, 19812 nonzeros
# ------
# Test with GLYFEM
# Solution: <Solution 4.933 at 0x7fc1043936a0>
# --------
# Read LP format model from file /var/folders/wy/8d18n83n56j78d4j6zkz449m0000gn/T/tmp85jccr2k.lp
# Reading time = 0.02 seconds
# : 1886 rows, 4524 columns, 19812 nonzeros
# ------
# Test with HMR_9726
# Solution: <Solution 0.156 at 0x7fc1122805b0>
# --------
# ['ARGDC',
#  'DHPS2_2',
#  'NRRH',
#  'CPS_1',
#  'SRK',
#  'GLY3Pt2',
#  'NP1_2',
#  'SDPDS_2',
#  'r1891',
#  'THDPS_2',
#  'GLYC3tr',
#  'HOMt4',
#  'OCBT2i',
#  'HMR_9726']

# %%
import requests, re

def get_valid_ec_number(annotations):
    ec_numbers = annotations.get('ec-code', [])
    for ec in ec_numbers:
        # Ensure the EC number has only digits and dots
        if re.match(r'^\d+(\.\d+)+$', ec):
            return ec
    return None

def check_annotation_uniprot(reaction_id, taxonomy_id):
    reaction = universal.reactions.get_by_id(reaction_id)
    ec_number = get_valid_ec_number(reaction.annotation)
    if ec_number is None:
        print(f"No valid EC number found for reaction {reaction_id}")
        return None
    
    print(f"Checking {reaction_id}, with ec {ec_number}")
    query = f'(taxonomy_id:{taxonomy_id}) AND (ec:{ec_number})'
    url = 'https://rest.uniprot.org/uniprotkb/search?'
    params = {
        'query': query,
        'format': 'json',
    }
    response = requests.get(url, params=params)
    if response.status_code == 200:
        return response.text
    else:
        print(f"Failed to retrieve data: {response.text}")
        return None

# %%
taxonomy_id = 1886

for r in short_list:
    result = check_annotation_uniprot(r, taxonomy_id)
    print(result)
# Out:
# Checking ARGDC, with ec 4.1.1.19
# {"results":[]}
# No valid EC number found for reaction DHPS2_2
# None
# No valid EC number found for reaction NRRH
# None
# No valid EC number found for reaction CPS_1
# None
# No valid EC number found for reaction SRK
# None
# No valid EC number found for reaction GLY3Pt2
# None
# No valid EC number found for reaction NP1_2
# None
# No valid EC number found for reaction SDPDS_2
# None
# No valid EC number found for reaction r1891
# None
# No valid EC number found for reaction THDPS_2
# None
# No valid EC number found for reaction GLYC3tr
# None
# No valid EC number found for reaction HOMt4
# None
# No valid EC number found for reaction OCBT2i
# None
# No valid EC number found for reaction HMR_9726
# None

# %%
# Test added reactions
temp_model = model.copy()
for reaction_id in short_list:
    # Get the reaction from the universal model
    reaction = universal.reactions.get_by_id(reaction_id)
    
    # Add a copy of the reaction to your model
    temp_model.add_reactions([reaction.copy()])
# Out:
# Read LP format model from file /var/folders/wy/8d18n83n56j78d4j6zkz449m0000gn/T/tmp5wr04hgq.lp
# Reading time = 0.02 seconds
# : 1886 rows, 4524 columns, 19812 nonzeros

# %%
def optimize_medium(model, bigg, type, exchange):
    """
    This function does optimize based on a chemical in the certain biolog medium and add an exchange reaction if needed
    """


    # when model has the exchange reaction, no need to add a reaction before gapfilling.    
    with model:
        medium = model.medium
        medium[exchange] = 0.8
        if type.startswith("C"):
            medium["EX_glc__D_e"] = 0

        elif type.startswith("N"):
            medium["EX_nh4_e"] = 0

        elif type.startswith("P"):
            medium["EX_pi_e"] = 0
        
        elif type.startswith("S"):
            medium["EX_so4_e"] = 0

        print(f"\n Optimize {bigg}, {type} with: ")
        model.medium = medium

        model.reactions.EX_co2_e.bounds= (0, 1000)
        model.solver = 'cplex'
        model.objective = 'growth'
        solution = model.optimize()
        print(solution.objective_value)
    return solution 
            
            
for ind in false_negatives.index:
    optimize_medium(temp_model, false_negatives['bigg'][ind], false_negatives['moa'][ind], false_negatives['exchange'][ind])
# Out:
#  Optimize met__L, C-Source, amino acid with:
# 0.0
#
#  Optimize citr__L, N-Source, amino acid with:
# 0.3253267107541947
#
#  Optimize hom__L, N-Source, amino acid with:
# 0.27110559229516656
#
#  Optimize thym, N-Source, other with:
# 0.16266335537709795
#
#  Optimize thymd, N-Source, other with:
# 0.2982161515246784
#
#  Optimize ura, N-Source, other with:
# 0.1693618164538203
#
#  Optimize uri, N-Source, other with:
# 0.31049666349867366
#
#  Optimize glyc3p, P-Source, organic with:
# 0.24399503306565254

# %% [markdown]
# # 3. Gapfill Untestables with Universal model

# %%
def add_exchange(model, reference, metabolite_bigg, metabolite_name):
    """
    This function aims to add an extra exchange reaction based on metabolite to the target model using reference model.
    
    Parameters:
    -----------
    metabolite_bigg: String
    metabolite_name: String
    model: Cobra Model
    reference: Cobra Model
    """
    try:
        ex_rxn_id = f"EX_{metabolite_bigg}_e"
        ex_met_id = f"{metabolite_bigg}_e"
        cy_met_id = f"{metabolite_bigg}_c"
        print(f"Try to add {ex_rxn_id} reaction")
        if any(r.id == ex_rxn_id for r in model.reactions.query(ex_rxn_id)):
            if model.reactions.get_by_id(ex_rxn_id).boundary == False:
                model.add_boundary(model.metabolites.get_by_id(ex_met_id), type="exchange")
            return model, ex_rxn_id

        else:
            # Check if the reaction is already in reference model, 
            # if yes, just copy reaction to model,
            # if not, add a new reaction.
            
                if reference.reactions.query(ex_rxn_id) != []:
                    ex_rxn = reference.reactions.get_by_id(ex_rxn_id)
                    model.add_reactions([ex_rxn.copy()])
                    print (f"Exchange: {ex_rxn_id} is added")
                
                else:
                    # Check if the metabolites is in target model in both cytosol and external
                    # if yes, create new reaction based on reference model
                    # if not, create new metabolite
                    if any(m.id == cy_met_id for m in reference.metabolites.query(cy_met_id)):
                        ex_rxn = Reaction(id=ex_rxn_id, name=f"{metabolite_name}-exchange")
                        model.add_reactions([ex_rxn])
                        met = reference.metabolites.get_by_id(cy_met_id).copy()
                        met.id = ex_met_id
                        met.compartment = 'e'
                        ex_rxn.add_metabolites({met: -1})                        
                        print(f"Exchange: {ex_rxn_id} is added")

                    elif any(m.id == ex_met_id for m in reference.metabolites.query(ex_met_id)):
                        ex_rxn = Reaction(id=ex_rxn_id, name=f"{metabolite_name}-exchange")
                        model.add_reactions([ex_rxn])
                        met = reference.metabolites.get_by_id(ex_met_id).copy()
                        ex_rxn.add_metabolites({met: -1})                        
                        print(f"Exchange: {ex_rxn_id} is added")
                    else:
                        print(f'{metabolite_bigg} is not in reference model\n')
                        return model, None
                # Final check to see if the boundary is added
                if model.reactions.get_by_id(ex_rxn_id).boundary == False:
                    model.add_boundary(model.metabolites.get_by_id(met.id), type="exchange")
                return model, ex_rxn_id
    except:
        return model, None

# %%
# All Untestable Growth Conditions ()
print(f"\nUntestable conditions:\n")

# Mapping of bigg and biolog model
untestables = pd.read_csv(f"{os.getcwd()}/../untestable_metabolites.csv", converters={'Ignore': lambda x: True if x == 'TRUE' else False})

# Join two tables together
untestables = untestables.merge(agreed_bio_data[['activity', 'index', 'moa', 'bigg']], on='bigg', how='left')
untestables['ignore'] = untestables['ignore'].replace({None: False, 'FALSE': True})
untestables = untestables[["bigg","name", "moa", "ignore"]]
# untestables.to_csv('untestables.csv')
untestables
# Out:
# Untestable conditions:
#       bigg                      name                        moa  ignore
# 0    2hbut  2 Hydroxybutyrate C4H7O3  C-Source, carboxylic acid   False
# 1    2obut            2-Oxobutanoate  C-Source, carboxylic acid   False
# 2      2pg   D-Glycerate 2-phosphate          P-Source, organic   False
# 3   2pglyc        2-Phosphoglycolate          P-Source, organic   False
# 4   35cgmp          3',5'-Cyclic GMP          P-Source, organic   False
# ..     ...                       ...                        ...     ...
# 77     tym                  Tyramine            N-Source, other   False
# 78    tyrp           Phosphotyrosine          P-Source, organic   False
# 79    tyrp           Phosphotyrosine          P-Source, organic   False
# 80   urate            Urate C5H4N4O3            N-Source, other   False
# 81  val__D                  D Valine       N-Source, amino acid   False
#
# [82 rows x 4 columns]

# %%
_model = model.copy()
with open('gapfill_reactions_uni_untestable.txt', 'w') as file:
    for ind in untestables.index:
        bigg = untestables['bigg'][ind]
        type = untestables['moa'][ind]
        name = untestables['name'][ind]

        # Only test ones that needs to be added
        if untestables['ignore'][ind] == False:
            file.write(f"Gapfilling {bigg}, {type} with:\n")
            print(f"---------------\nGapfilling {bigg}, {type} test:\n")
            # Try to add exchange reactions before gapfilling
            _model, ex_rxn = add_exchange(_model, universal, bigg, name)
            solution = None
            if ex_rxn:
                solution = gapfill_medium(_model, universal, bigg, type, ex_rxn)

            # Write gapfilling results
            if solution:
                unique_solution = set([reaction for reaction_set in solution for reaction in reaction_set])
                reactions_str = ', '.join(str(reaction.id) for reaction in unique_solution)
                file.write(reactions_str + '\n\n')
            else:
                file.write('\n\n')
# Out:
# Read LP format model from file /var/folders/wy/8d18n83n56j78d4j6zkz449m0000gn/T/tmpr7q_wsns.lp
# Reading time = 0.02 seconds
# : 1886 rows, 4524 columns, 19812 nonzeros
# ---------------
# Gapfilling 2hbut, C-Source, carboxylic acid test:
#
# Try to add EX_2hbut_e reaction
# Exchange: EX_2hbut_e is added
#
# Gapfilling 2hbut with:
# [[<Reaction SLGTH at 0x7fc25dba7640>], [<Reaction GLYFEM at 0x7fc12642aca0>], [<Reaction FACT at 0x7fc124cf5610>], [<Reaction SUCptspp_1 at 0x7fc125f67df0>]]
# ---------------
# Gapfilling 2obut, C-Source, carboxylic acid test:
#
# Try to add EX_2obut_e reaction
# Exchange: EX_2obut_e is added
#
# Gapfilling 2obut with:
# [[<Reaction SUCptspp_1 at 0x7fc0a2117880>], [<Reaction SLGTH at 0x7fc1678650d0>], [<Reaction SK_coa_c at 0x7fc1673bb1f0>], [<Reaction 2OBUT_Et at 0x7fc16776e0a0>]]
# ---------------
# Gapfilling 2pg, P-Source, organic test:
#
# Try to add EX_2pg_e reaction
# Exchange: EX_2pg_e is added
#
# Gapfilling 2pg with:
# [[<Reaction DHPS2_2 at 0x7fc090a401f0>], [<Reaction CPS_1 at 0x7fc08c932bb0>], [<Reaction P5CCD at 0x7fc082a2a070>], [<Reaction 2PGt6 at 0x7fc0c4038c10>]]
# ---------------
# Gapfilling 2pglyc, P-Source, organic test:
#
# Try to add EX_2pglyc_e reaction
# Exchange: EX_2pglyc_e is added
#
# Gapfilling 2pglyc with:
# [[<Reaction DHPS2_2 at 0x7fc062eb7370>], [<Reaction NADPPPS at 0x7fc0e21a9b80>], [<Reaction P5CCD at 0x7fc04353b1f0>], [<Reaction CPS_1 at 0x7fc0a39a9d30>]]
# ---------------
# Gapfilling 35cgmp, P-Source, organic test:
#
# Try to add EX_35cgmp_e reaction
# Exchange: EX_35cgmp_e is added
#
# Gapfilling 35cgmp with:
# [[<Reaction DHPS2_2 at 0x7fc0e4b126a0>], [<Reaction CPS_1 at 0x7fc093b690a0>], [<Reaction NADPPPS at 0x7fc09597feb0>], [<Reaction THPPP at 0x7fc09481bee0>]]
# ---------------
# Gapfilling 35cgmp, P-Source, organic test:
#
# Try to add EX_35cgmp_e reaction
#
# Gapfilling 35cgmp with:
# [[<Reaction DHPS2_2 at 0x7fc0cdc25880>], [<Reaction CPS_1 at 0x7fc0f248a280>], [<Reaction NADPPPS at 0x7fc0b81670d0>], [<Reaction THPPP at 0x7fc0b8741100>]]
# ---------------
# Gapfilling 3hoxpac, C-Source, carboxylic acid test:
#
# Try to add EX_3hoxpac_e reaction
# Exchange: EX_3hoxpac_e is added
#
# Gapfilling 3hoxpac with:
# [[<Reaction SLGTH at 0x7fc0cde5b310>], [<Reaction SK_coa_c at 0x7fc06ba8a430>], [<Reaction FACT at 0x7fc0f0bdf2e0>], [<Reaction SUCptspp_1 at 0x7fc0a95afac0>]]
# ---------------
# Gapfilling 3pg, P-Source, organic test:
#
# Try to add EX_3pg_e reaction
# Exchange: EX_3pg_e is added
#
# Gapfilling 3pg with:
# [[<Reaction DHPS2_2 at 0x7fc054ce9ac0>], [<Reaction NADPPPS at 0x7fc0b81b1310>], [<Reaction THPPP at 0x7fc0f7b11340>], [<Reaction CPS_1 at 0x7fc0f7faa4c0>]]
# ---------------
# Gapfilling 5aptn, C-Source, carboxylic acid test:
#
# Try to add EX_5aptn_e reaction
# Exchange: EX_5aptn_e is added
#
# Gapfilling 5aptn with:
# [[<Reaction SLGTH at 0x7fbff46337f0>], [<Reaction SUCptspp_1 at 0x7fbfe27dbfa0>], [<Reaction FACT at 0x7fbff37d87c0>], [<Reaction GLYFEM at 0x7fbff0b86e50>]]
# ---------------
# Gapfilling 5aptn, N-Source, other test:
#
# Try to add EX_5aptn_e reaction
#
# Gapfilling 5aptn with:
# [[<Reaction SLGTH at 0x7fc002ac8d00>], [<Reaction SDPDS_2 at 0x7fc002aa9310>], [<Reaction HMR_9726 at 0x7fbfc76ccd30>], [<Reaction NRRH at 0x7fc002aa9430>]]
# ---------------
# Gapfilling 6ax, N-Source, other test:
#
# Try to add EX_6ax_e reaction
# Exchange: EX_6ax_e is added
#
# Gapfilling 6ax with:
# [[<Reaction SLGTH at 0x7fbfe9829e80>], [<Reaction NRRH at 0x7fbf940aa5b0>], [<Reaction THDPS_2 at 0x7fbfec24d6d0>], [<Reaction NP1_2 at 0x7fbfec24d760>]]
# ---------------
# Gapfilling 6pgc, P-Source, organic test:
#
# Try to add EX_6pgc_e reaction
# Exchange: EX_6pgc_e is added
#
# Gapfilling 6pgc with:
# [[<Reaction 6PGCt6 at 0x7fbf70d1e580>], [<Reaction DHPS2_2 at 0x7fbf70442760>], [<Reaction CPS_1 at 0x7fbfca038160>], [<Reaction P5CCD at 0x7fbfc9c385e0>]]
# ---------------
# Gapfilling acgal, C-Source, carbohydrate test:
#
# Try to add EX_acgal_e reaction
# Exchange: EX_acgal_e is added
#
# Gapfilling acgal with:
# [[<Reaction GLYFEM at 0x7fbf554c4460>], [<Reaction ACCDH at 0x7fbf554632e0>], [<Reaction FACT at 0x7fbf57fdfd90>], [<Reaction SUCptspp_1 at 0x7fbf54e775b0>]]
# ---------------
# Gapfilling acgal, N-Source, other test:
#
# Try to add EX_acgal_e reaction
#
# Gapfilling acgal with:
# [[<Reaction SLGTH at 0x7fbf62aecf40>], [<Reaction NP1_2 at 0x7fbfb754d820>], [<Reaction HMR_9726 at 0x7fc00c5a6f70>], [<Reaction SRK at 0x7fc00c64b9a0>]]
# ---------------
# Gapfilling acgam, C-Source, carbohydrate test:
#
# Try to add EX_acgam_e reaction
# Exchange: EX_acgam_e is added
#
# Gapfilling acgam with:
# [[], [], [], []]
# ---------------
# Gapfilling acgam, N-Source, other test:
#
# Try to add EX_acgam_e reaction
#
# Gapfilling acgam with:
# [[], [], [], []]
# ---------------
# Gapfilling acmana, C-Source, carbohydrate test:
#
# Try to add EX_acmana_e reaction
# Exchange: EX_acmana_e is added
#
# Gapfilling acmana with:
# [[<Reaction SLGTH at 0x7fbef15771f0>], [<Reaction SK_coa_c at 0x7fbf3689e310>], [<Reaction SUCptspp_1 at 0x7fbf359ba9a0>], [<Reaction FACT at 0x7fbf36aed1c0>]]
# ---------------
# Gapfilling acmana, N-Source, other test:
#
# Try to add EX_acmana_e reaction
#
# Gapfilling acmana with:
# [[<Reaction SLGTH at 0x7fbf59bf8430>], [<Reaction THDPS_2 at 0x7fbf9e86ec40>], [<Reaction SRK at 0x7fbf2ef8fe50>], [<Reaction NP1_2 at 0x7fbf9e86ecd0>]]
# ---------------
# Gapfilling ad, C-Source, amide test:
#
# Try to add EX_ad_e reaction
# Exchange: EX_ad_e is added
#
# Gapfilling ad with:
# [[<Reaction FACT at 0x7fbee672cfa0>], [<Reaction SLGTH at 0x7fc0ecd61fd0>], [<Reaction SUCptspp_1 at 0x7fbe795287c0>], [<Reaction ACCDH at 0x7fbec7ca24f0>]]
# ---------------
# Gapfilling ad, N-Source, other test:
#
# Try to add EX_ad_e reaction
#
# Gapfilling ad with:
# [[<Reaction SDPDS_2 at 0x7fbee1035940>], [<Reaction SLGTH at 0x7fbea0244370>], [<Reaction HMR_9726 at 0x7fc00d23e3a0>], [<Reaction THDPS_2 at 0x7fbe77eb4b80>]]
# ---------------
# Gapfilling agm, N-Source, other test:
#
# Try to add EX_agm_e reaction
# Exchange: EX_agm_e is added
#
# Gapfilling agm with:
# [[], [], [], []]
# ---------------
# Gapfilling alltn, N-Source, other test:
#
# Try to add EX_alltn_e reaction
# Exchange: EX_alltn_e is added
#
# Gapfilling alltn with:
# [[], [], [], []]
# ---------------
# Gapfilling amp2p, P-Source, organic test:
#
# Try to add EX_amp2p_e reaction
# Exchange: EX_amp2p_e is added
#
# Gapfilling amp2p with:
# Gapfilling of the compound amp2p - P-Source, organic - EX_amp2p_e is failed
#
# ---------------
# Gapfilling arab__D, C-Source, carbohydrate test:
#
# Try to add EX_arab__D_e reaction
# Exchange: EX_arab__D_e is added
#
# Gapfilling arab__D with:
# [[<Reaction SLGTH at 0x7fbdf4226670>], [<Reaction GLYFEM at 0x7fbdf3047cd0>], [<Reaction SUCptspp_1 at 0x7fbdf7581e20>], [<Reaction ACCDH at 0x7fbdf2ee5b50>]]
# ---------------
# Gapfilling arbt, C-Source, carbohydrate test:
#
# Try to add EX_arbt_e reaction
# Exchange: EX_arbt_e is added
#
# Gapfilling arbt with:
# [[<Reaction SUCptspp_1 at 0x7fbe17008c40>], [<Reaction SLGTH at 0x7fbdf7353490>], [<Reaction GLYFEM at 0x7fbecd64aaf0>], [<Reaction FACT at 0x7fbf63e5a460>]]
# ---------------
# Gapfilling argp, P-Source, organic test:
#
# Try to add EX_argp_e reaction
# Exchange: EX_argp_e is added
#
# Gapfilling argp with:
# [[<Reaction DHPS2_2 at 0x7fbdc7dc1df0>], [<Reaction P5CCD at 0x7fbd94f3ec70>], [<Reaction CPS_1 at 0x7fbd9c5917f0>], [<Reaction NADPPPS at 0x7fbda32f5640>]]
# ---------------
# Gapfilling asn__D, N-Source, amino acid test:
#
# Try to add EX_asn__D_e reaction
# Exchange: EX_asn__D_e is added
#
# Gapfilling asn__D with:
# [[<Reaction SLGTH at 0x7fbd49a47310>], [<Reaction HMR_9726 at 0x7fbd4c004340>], [<Reaction SRK at 0x7fbd496f3d30>], [<Reaction SDPDS_2 at 0x7fbd49a128e0>]]
# ---------------
# Gapfilling but, C-Source, carboxylic acid test:
#
# Try to add EX_but_e reaction
# Exchange: EX_but_e is added
#
# Gapfilling but with:
# [[<Reaction SUCptspp_1 at 0x7fbdc7907b80>], [<Reaction ACCDH at 0x7fbed06b68b0>], [<Reaction FACT at 0x7fbd57bb13a0>], [<Reaction GLYFEM at 0x7fbecb4eaa30>]]
# ---------------
# Gapfilling camp, P-Source, organic test:
#
# Try to add EX_camp_e reaction
# Exchange: EX_camp_e is added
#
# Gapfilling camp with:
# [[<Reaction DHPS2_2 at 0x7fbd10a69310>], [<Reaction P5CCD at 0x7fbd37d6a190>], [<Reaction NADPPPS at 0x7fbd10db1b20>], [<Reaction CPS_1 at 0x7fbd37e11cd0>]]
# ---------------
# Gapfilling cbp, P-Source, organic test:
#
# Try to add EX_cbp_e reaction
# Exchange: EX_cbp_e is added
#
# Gapfilling cbp with:
# [[<Reaction DHPS2_2 at 0x7fbcd20ad160>], [<Reaction NADPPPS at 0x7fbdb75c2970>], [<Reaction CPS_1 at 0x7fbd29b6fb20>], [<Reaction P5CCD at 0x7fbd2c1fafa0>]]
# ---------------
# Gapfilling CE0074, N-Source, other test:
#
# Try to add EX_CE0074_e reaction
# Exchange: EX_CE0074_e is added
#
# Gapfilling CE0074 with:
# [[<Reaction NP1_2 at 0x7fbebf16f550>], [<Reaction SLGTH at 0x7fbe00767c70>], [<Reaction SRK at 0x7fbd37c4a6d0>], [<Reaction NRRH at 0x7fbd206e63a0>]]
# ---------------
# Gapfilling cholp, P-Source, organic test:
#
# Try to add EX_cholp_e reaction
# Exchange: EX_cholp_e is added
#
# Gapfilling cholp with:
# [[<Reaction DHPS2_2 at 0x7fbce48f42e0>], [<Reaction NADPPPS at 0x7fbced502af0>], [<Reaction P5CCD at 0x7fbcb4f18160>], [<Reaction CPS_1 at 0x7fbcb5abbca0>]]
# ---------------
# Gapfilling citr__L, N-Source, amino acid test:
#
# Try to add EX_citr__L_e reaction
#
# Gapfilling citr__L with:
# [[<Reaction SLGTH at 0x7fbc78609100>], [<Reaction OCBT2i at 0x7fbd11638a00>], [<Reaction NRRH at 0x7fbc785977f0>], [<Reaction SRK at 0x7fbc7823cb20>]]
# ---------------
# Gapfilling ethamp, P-Source, organic test:
#
# Try to add EX_ethamp_e reaction
# Exchange: EX_ethamp_e is added
#
# Gapfilling ethamp with:
# [[<Reaction DHPS2_2 at 0x7fbc906ee9d0>], [<Reaction NADPPPS at 0x7fbc9110b220>], [<Reaction CPS_1 at 0x7fbc30a523d0>], [<Reaction P5CCD at 0x7fbc308b7850>]]
# ---------------
# Gapfilling frmd, N-Source, other test:
#
# Try to add EX_frmd_e reaction
# Exchange: EX_frmd_e is added
#
# Gapfilling frmd with:
# [[<Reaction SDPDS_2 at 0x7fbc56e121f0>], [<Reaction SRK at 0x7fbc747ef640>], [<Reaction SLGTH at 0x7fbc56e2dbe0>], [<Reaction HMR_9726 at 0x7fbc57a52c10>]]
# ---------------
# Gapfilling g1p, C-Source, carbohydrate test:
#
# Try to add EX_g1p_e reaction
# Exchange: EX_g1p_e is added
#
# Gapfilling g1p with:
# [[<Reaction SUCptspp_1 at 0x7fbc11681c10>], [<Reaction SK_coa_c at 0x7fbc923d3580>], [<Reaction G1Pt6_2 at 0x7fbc94d675e0>], [<Reaction GLYFEM at 0x7fbc40985ac0>]]
# ---------------
# Gapfilling g1p, P-Source, organic test:
#
# Try to add EX_g1p_e reaction
#
# Gapfilling g1p with:
# Gapfilling of the compound g1p - P-Source, organic - EX_g1p_e is failed
#
# ---------------
# Gapfilling g6p, C-Source, carbohydrate test:
#
# Try to add EX_g6p_e reaction
# Exchange: EX_g6p_e is added
#
# Gapfilling g6p with:
# [[<Reaction G6Pt6_2 at 0x7fbc776c3850>], [<Reaction FACT at 0x7fbc4eb7e040>], [<Reaction SUCptspp_1 at 0x7fbc4eebd820>], [<Reaction SLGTH at 0x7fbc4ea93070>]]
# ---------------
# Gapfilling g6p, P-Source, organic test:
#
# Try to add EX_g6p_e reaction
#
# Gapfilling g6p with:
# [[<Reaction DHPS2_2 at 0x7fbcd512ac70>], [<Reaction G6Pt6_2 at 0x7fbbb0a92100>], [<Reaction THPPP at 0x7fbe32ede4f0>], [<Reaction NADPPPS at 0x7fbd623634c0>]]
# ---------------
# Gapfilling gam, C-Source, carbohydrate test:
#
# Try to add EX_gam_e reaction
# Exchange: EX_gam_e is added
#
# Gapfilling gam with:
# [[], [], [], []]
# ---------------
# Gapfilling gam, N-Source, other test:
#
# Try to add EX_gam_e reaction
#
# Gapfilling gam with:
# [[], [], [], []]
# ---------------
# Gapfilling gam6p, P-Source, organic test:
#
# Try to add EX_gam6p_e reaction
# Exchange: EX_gam6p_e is added
#
# Gapfilling gam6p with:
# [[<Reaction GAM6Pt at 0x7fbe950edb80>], [<Reaction DHPS2_2 at 0x7fbb41bf26a0>], [<Reaction NADPPPS at 0x7fbb41d8ceb0>], [<Reaction P5CCD at 0x7fbe96cb7520>]]
# ---------------
# Gapfilling glx, C-Source, carboxylic acid test:
#
# Try to add EX_glx_e reaction
# Exchange: EX_glx_e is added
#
# Gapfilling glx with:
# Gapfilling of the compound glx - C-Source, carboxylic acid - EX_glx_e is failed
#
# ---------------
# Gapfilling glyc2p, P-Source, organic test:
#
# Try to add EX_glyc2p_e reaction
# Exchange: EX_glyc2p_e is added
#
# Gapfilling glyc2p with:
# Gapfilling of the compound glyc2p - P-Source, organic - EX_glyc2p_e is failed
#
# ---------------
# Gapfilling hxa, C-Source, carboxylic acid test:
#
# Try to add EX_hxa_e reaction
# Exchange: EX_hxa_e is added
#
# Gapfilling hxa with:
# [[<Reaction SLGTH at 0x7fbb41e4cb20>], [<Reaction SUCptspp_1 at 0x7fbab2e64310>], [<Reaction SK_coa_c at 0x7fbb42015c40>], [<Reaction GLYFEM at 0x7fbb411d81c0>]]
# ---------------
# Gapfilling mal__D, C-Source, carboxylic acid test:
#
# Try to add EX_mal__D_e reaction
# Exchange: EX_mal__D_e is added
#
# Gapfilling mal__D with:
# Gapfilling of the compound mal__D - C-Source, carboxylic acid - EX_mal__D_e is failed
#
# ---------------
# Gapfilling mal__D, C-Source, carboxylic acid test:
#
# Try to add EX_mal__D_e reaction
#
# Gapfilling mal__D with:
# Gapfilling of the compound mal__D - C-Source, carboxylic acid - EX_mal__D_e is failed
#
# ---------------
# Gapfilling malon, C-Source, carboxylic acid test:
#
# Try to add EX_malon_e reaction
# Exchange: EX_malon_e is added
#
# Gapfilling malon with:
# [[<Reaction SLGTH at 0x7fba469e79a0>], [<Reaction GLYFEM at 0x7fba3890f040>], [<Reaction SUCptspp_1 at 0x7fba317fe190>], [<Reaction SK_coa_c at 0x7fba3a13cac0>]]
# ---------------
# Gapfilling man1p, P-Source, organic test:
#
# Try to add EX_man1p_e reaction
# Exchange: EX_man1p_e is added
#
# Gapfilling man1p with:
# [[<Reaction DHPS2_2 at 0x7fbb0695f250>], [<Reaction P5CCD at 0x7fba467bb0d0>], [<Reaction MAN1Pt6 at 0x7fba391340d0>], [<Reaction CPS_1 at 0x7fbae7682c10>]]
# ---------------
# Gapfilling man6p, P-Source, organic test:
#
# Try to add EX_man6p_e reaction
# Exchange: EX_man6p_e is added
#
# Gapfilling man6p with:
# Gapfilling of the compound man6p - P-Source, organic - EX_man6p_e is failed
#
# ---------------
# Gapfilling mbdg, C-Source, carbohydrate test:
#
# Try to add EX_mbdg_e reaction
# Exchange: EX_mbdg_e is added
#
# Gapfilling mbdg with:
# Gapfilling of the compound mbdg - C-Source, carbohydrate - EX_mbdg_e is failed
#
# ---------------
# Gapfilling minohp, P-Source, organic test:
#
# Try to add EX_minohp_e reaction
# Exchange: EX_minohp_e is added
#
# Gapfilling minohp with:
# [[<Reaction DHPS2_2 at 0x7fba24b48880>], [<Reaction NADPPPS at 0x7fb9de63b0d0>], [<Reaction P5CCD at 0x7fb9dfa96700>], [<Reaction THPPP at 0x7fb9dfa7b100>]]
# ---------------
# Gapfilling pcreat, P-Source, organic test:
#
# Try to add EX_pcreat_e reaction
# Exchange: EX_pcreat_e is added
#
# Gapfilling pcreat with:
# [[<Reaction DHPS2_2 at 0x7fb992f78940>], [<Reaction NADPPPS at 0x7fb9932b5190>], [<Reaction P5CCD at 0x7fb9a61ca7c0>], [<Reaction CPS_1 at 0x7fb992321340>]]
# ---------------
# Gapfilling peamn, C-Source, amine test:
#
# Try to add EX_peamn_e reaction
# Exchange: EX_peamn_e is added
#
# Gapfilling peamn with:
# [[<Reaction SLGTH at 0x7fba5e8aec10>], [<Reaction GLYFEM at 0x7fb9c3ff72b0>], [<Reaction SUCptspp_1 at 0x7fba606d8400>], [<Reaction SK_coa_c at 0x7fbb72f3ad30>]]
# ---------------
# Gapfilling peamn, N-Source, other test:
#
# Try to add EX_peamn_e reaction
#
# Gapfilling peamn with:
# [[<Reaction NP1_2 at 0x7fb9752fc5e0>], [<Reaction SLGTH at 0x7fb976177d00>], [<Reaction SDPDS_2 at 0x7fb976169310>], [<Reaction THDPS_2 at 0x7fb9752fc550>]]
# ---------------
# Gapfilling pep, P-Source, organic test:
#
# Try to add EX_pep_e reaction
# Exchange: EX_pep_e is added
#
# Gapfilling pep with:
# [[<Reaction PEPt6 at 0x7fb8fa32c0a0>], [<Reaction DHPS2_2 at 0x7fb96491d550>], [<Reaction P5CCD at 0x7fb96a10b3d0>], [<Reaction CPS_1 at 0x7fb96b2b4f10>]]
# ---------------
# Gapfilling pser__D, P-Source, organic test:
#
# Try to add EX_pser__D_e reaction
# Exchange: EX_pser__D_e is added
#
# Gapfilling pser__D with:
# [[<Reaction DHPS2_2 at 0x7fb8e2de2be0>], [<Reaction P5CCD at 0x7fb8d6807a60>], [<Reaction NADPPPS at 0x7fb8e32fc430>], [<Reaction CPS_1 at 0x7fb8d6a495e0>]]
# ---------------
# Gapfilling pser__L, P-Source, organic test:
#
# Try to add EX_pser__L_e reaction
# Exchange: EX_pser__L_e is added
#
# Gapfilling pser__L with:
# [[<Reaction NADPPPS at 0x7fb8b7dd8c70>], [<Reaction DHPS2_2 at 0x7fb945770460>], [<Reaction PSER_Lt6 at 0x7fb8b4969130>], [<Reaction P5CCD at 0x7fb8b38aa2e0>]]
# ---------------
# Gapfilling salcn, C-Source, carbohydrate test:
#
# Try to add EX_salcn_e reaction
# Exchange: EX_salcn_e is added
#
# Gapfilling salcn with:
# [[], [], [], []]
# ---------------
# Gapfilling thrp, P-Source, organic test:
#
# Try to add EX_thrp_e reaction
# Exchange: EX_thrp_e is added
#
# Gapfilling thrp with:
# [[<Reaction DHPS2_2 at 0x7fb95a616820>], [<Reaction CPS_1 at 0x7fb981690220>], [<Reaction P5CCD at 0x7fb95dc5b6a0>], [<Reaction NADPPPS at 0x7fb95a77e070>]]
# ---------------
# Gapfilling tmp, P-Source, inorganic test:
#
# Try to add EX_tmp_e reaction
# Exchange: EX_tmp_e is added
#
# Gapfilling tmp with:
# [[<Reaction DHPS2_2 at 0x7fb887535550>], [<Reaction P5CCD at 0x7fb9316323d0>], [<Reaction CPS_1 at 0x7fb931899f10>], [<Reaction NADPPPS at 0x7fb877c11d60>]]
# ---------------
# Gapfilling tym, C-Source, amine test:
#
# Try to add EX_tym_e reaction
# Exchange: EX_tym_e is added
#
# Gapfilling tym with:
# [[<Reaction SLGTH at 0x7fb8567ee100>], [<Reaction SUCptspp_1 at 0x7fb857f538b0>], [<Reaction FACT at 0x7fb8554900d0>], [<Reaction ACCDH at 0x7fb831cfc5e0>]]
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Initialize an empty list to store the extracted lists
gapfill_lists = []

# Open and read the file
with open('gapfill_reactions_uni_untestable.txt', 'r') as file:
    lines = file.readlines()

# Process every second line and split it into a list
for i in range(1, len(lines), 3):
    reaction_list = [item.strip() for item in lines[i].strip().split(',')]
    gapfill_lists.extend(reaction_list)

merged_lists = set(gapfill_lists)
merged_lists.discard('')

# Print the extracted lists
print(merged_lists)
# Out:
# {'GAMpts', 'ACGApts', 'ARGAGMt7', 'SALCpts', 'ALLTNt2r'}

# %%
for reaction_id in merged_lists:
    # Get the reaction from the universal model
    reaction = universal.reactions.get_by_id(reaction_id)
    
    # Add a copy of the reaction to your model
    model.add_reactions([reaction.copy()])

# %%
model.reactions.EX_co2_e.bounds= (0, 1000)

cobra.io.write_sbml_model(temp_model, 'Salb-GEM-Uni-gapfill.xml')
